# %%
#!/usr/bin/python3
# !pip3 install flask
from flask import Flask, request, render_template, make_response, redirect, url_for

app = Flask(__name__)

try:
    FLAG = open('./flag.txt', 'r').read()
except:
    FLAG = '[**FLAG**]'

users = {
    'guest': 'guest',
    'admin': FLAG
}

@app.route('/')
def index():
    username = request.cookies.get('username', None)
    if username:
        return render_template('index.html', text=f'Hello {username}, {"flag is " + FLAG if username == "admin" else "you are not admin"}')
    return render_template('index.html')

@app.route('/login', methods=['GET', 'POST'])
def login():
    if request.method == 'GET':
        return render_template('login.html')
    elif request.method == 'POST':
        username = request.form.get('username')
        password = request.form.get('password')
        try:
            pw = users[username]
        except:
            return '<script>alert("not found user");history.go(-1);</script>'
        if pw == password:
            resp = make_response(redirect(url_for('index')) )
            resp.set_cookie('username', username)
            return resp 
        return '<script>alert("wrong password");history.go(-1);</script>'

app.run(host='0.0.0.0', port=8000)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: flask in /Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages (2.1.1)
# Requirement already satisfied: Werkzeug>=2.0 in /Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages (from flask) (2.1.1)
# Requirement already satisfied: click>=8.0 in /Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages (from flask) (8.1.2)
# Requirement already satisfied: Jinja2>=3.0 in /Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages (from flask) (3.0.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages (from flask) (4.11.3)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages (from flask) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages (from importlib-metadata>=3.6.0->flask) (3.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages (from Jinja2>=3.0->flask) (2.1.0)
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses (0.0.0.0)
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://127.0.0.1:8000
#  * Running on http://192.9.200.176:8000 (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Apr/2022 14:48:21] "GET /user='admin' HTTP/1.1" 404 -
# [2022-04-28 14:48:25,713] ERROR in app: Exception on /login [GET]
# Traceback (most recent call last):
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 2077, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1525, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1523, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1509, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/var/folders/ds/3pccrhwd1hb9q3h_5q7b1cp80000gn/T/ipykernel_2923/3746062663.py", line 27, in login
#     return render_template('login.html')
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 149, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: login.html
# 127.0.0.1 - - [28/Apr/2022 14:48:25] "GET /login HTTP/1.1" 500 -
# 127.0.0.1 - - [28/Apr/2022 14:48:56] "GET /login/username='admin' HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Apr/2022 14:49:02] "GET /login/username= HTTP/1.1" 404 -
# [2022-04-28 14:49:05,082] ERROR in app: Exception on /login [GET]
# Traceback (most recent call last):
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 2077, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1525, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1523, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1509, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/var/folders/ds/3pccrhwd1hb9q3h_5q7b1cp80000gn/T/ipykernel_2923/3746062663.py", line 27, in login
#     return render_template('login.html')
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 149, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: login.html
# 127.0.0.1 - - [28/Apr/2022 14:49:05] "GET /login HTTP/1.1" 500 -
# [2022-04-28 14:49:14,385] ERROR in app: Exception on /login [GET]
# Traceback (most recent call last):
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 2077, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1525, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1523, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/app.py", line 1509, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/var/folders/ds/3pccrhwd1hb9q3h_5q7b1cp80000gn/T/ipykernel_2923/3746062663.py", line 27, in login
#     return render_template('login.html')
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 149, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/aebdeung-ichangmin-ing/Library/Python/3.8/lib/python/site-packages/flask/templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: login.html
# 127.0.0.1 - - [28/Apr/2022 14:49:14] "GET /login HTTP/1.1" 500 -
