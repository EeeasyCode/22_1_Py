# %% [markdown]
# # 03.파이썬라이브러리-Matplotlib

# %% [markdown]
# ### matplotlib 설치하기

# %%
# !pip install matplotlib    # 최초 한번만 실행하기

# %% [markdown]
# -----------

# %% [markdown]
# ### matplotlib 사용하기

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### matplotlib 사용 예:

# %%
import matplotlib
import matplotlib.pyplot as plt

# 한글출력 설정
matplotlib.rcParams['font.family'] = 'Malgun Gothic'   

# 그래프 크기 설정
plt.rcParams['figure.figsize'] = (10, 5)  # (가로,세로) 인치 단위
#plt.figure(figsize=(10, 5))

# X축, Y축 데이터
X = list(range(2005,2015,1))
Y = [15,7,2,10,8,5,14,9,18,8]


plt.plot(X, Y, c='r')     #선 그래프
plt.grid(True)
plt.title('년도별 그래프')
plt.show()

# %% [markdown]
# ### matplotlib  선그래프 나타내기

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 한글출력 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # '맑은 고딕'으로 설정 
plt.rcParams['axes.unicode_minus'] = False     # 그래프에서 (-)숫자표시

# 그래프 크기 설정
plt.rcParams['figure.figsize'] = (10, 5) # 그래프(figure)의 크기, (가로,세로) 인치 단위
plt.rcParams['lines.linewidth'] = 3      # 선 두께
plt.rcParams['axes.grid'] = True 

data    = [[15,7,2,10,8,5,14,9,18,8]]  
columns = list(range(2005,2015,1))
index   = ['횟수']

df = pd.DataFrame(data, columns=columns, index=index)
df.columns.name = '연도'

x = df.columns    #x = df.columns
y = df.values[0]  #y = df.values[0]

plt.plot(x, y, 'o', linestyle='dashed', c='b')
plt.title('년도별 그래프')
plt.show()

# %% [markdown]
# ### [실습] : 2개 선그래프 나타내기

# %%
import matplotlib.pyplot as plt

# 한글출력 설정
plt.rcParams['font.family'] = 'Malgun Gothic'   

# 그래프 크기 설정
plt.rcParams['figure.figsize'] = (10, 5)  # (가로,세로) 인치 단위

# X축, Y축 데이터
X1 = list(range(2005,2015,1))
X2 = list(range(2008,2018,1))
Y = [15,7,2,10,8,5,14,9,18,8]

plt.plot(X1, Y, 'o', linestyle='solid', c='c', label='X1')     #선 그래프
plt.plot(X2, Y, 'X', linestyle='solid', c='m', label='X2')     #선 그래프
plt.title('년도별 그래프')
plt.grid(False)
plt.legend()
plt.show()

# %% [markdown]
# ### 선 그래프 : numpy 데이터

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([10,14,19,20,25])
plt.plot(a)

a2 = np.arange(20)
plt.plot(a2)

plt.show()

# %% [markdown]
# ### 2차 방정식의 그래프 : f(x) = a*x^2 + b, 포물선 방정식

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-4.5,5,0.5)
y = 2*x**2
plt.plot(x, y)

plt.plot(x, 4*x)
plt.plot(x,-3*x)
plt.show()

# %% [markdown]
# -------

# %% [markdown]
# ### 막대 그래프 나타내기

# %%
import matplotlib.pyplot as plt

# 한글출력 설정
plt.rcParams['font.family'] = 'Malgun Gothic'   

# 그래프 크기 설정
plt.rcParams['figure.figsize'] = (10, 5)  # (가로,세로) 인치 단위

# X축, Y축 데이터
X = list(range(2005,2015,1))
Y = [15,7,2,10,8,5,14,9,18,8]

plt.bar(X, Y)     # 막대 그래프
plt.grid(False)
plt.title('년도별 그래프')
plt.show()

# %%
plt.barh(X, Y)     # 막대 그래프
plt.grid(False)
plt.title('년도별 그래프')
plt.show()

# %%
#그래프 색상 지정
colors = ['r','g','b','c','m','y','k','w']  # 기본색상  # Hexa코드 or CSS컬러사용
plt.bar(X, Y,color=colors)
plt.show()

# %%
import matplotlib.pyplot as plt

# 한글출력 설정
plt.rcParams['font.family'] = 'Malgun Gothic'   

# 그래프 크기 설정
plt.rcParams['figure.figsize'] = (10, 5)  # (가로,세로) 인치 단위

# X축, Y축 데이터
X1 = list(range(2005,2015,1))
X2 = [x+3 for x in X1]
Y = [15,7,2,10,8,5,14,9,18,8]

plt.bar(X1, Y)     # 막대 그래프
plt.bar(X2, Y)     # 막대 그래프
plt.title('년도별 그래프')
plt.grid(False)
plt.show()

# %% [markdown]
# ### 2개 막대 그래프

# %%
import matplotlib.pyplot as plt
import numpy as np

# 한글출력 설정
plt.rcParams['font.family'] = 'Malgun Gothic'   

# 그래프 크기 설정
plt.rcParams['figure.figsize'] = (10, 5)  

# X축, Y축 데이터
X = list(range(2005,2015,1))
Y1= [15,7,2,10,8,5,14,9,18,8]
Y2= [y+1 for y in Y1]
lable = X
X = np.arange(len(X))

plt.bar(X-0.2, Y1, width=0.4, label='Y1')     # 막대 그래프
plt.bar(X+0.2, Y2, width=0.4, label='Y2')     # 막대 그래프
plt.xticks(X, lable)

plt.title('년도별 그래프')
plt.grid(False)
plt.legend()
plt.show()

# %%
# X축, Y축 데이터
X = list(range(2005,2015,1))
Y1= [15,7,2,10,8,5,14,9,18,8]
Y2= [y+1 for y in Y1]

plt.plot(X, Y1, 'o', linestyle='dashed', c='r', label='Y1') # 선 그래프
plt.bar(X, Y2, width=0.4, label='Y2')     # 막대 그래프
plt.xticks(X, lable)

plt.title('년도별 그래프')
plt.grid(False)
plt.legend()
plt.show()

# %% [markdown]
# -------

# %% [markdown]
# ### 원 그래프

# %%
import matplotlib.pyplot as plt 
import pandas as pd

idx = ['1학년','2학년','3학년','4학년']
val = [16,12,7,5]
per = [val[x]/sum(val) *100 for x in range(len(val))]

plt.pie(per, autopct='%1.1f%%',
              textprops=dict(color="w"))
plt.title("학년별 동아리 회원수")
plt.legend(idx, title='학년', loc="center right",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ----------

# %% [markdown]
# # 04. 실습:공공데이터 분석

# %% [markdown]
# ###  공공데이터 수집
#
# - 기상청 사이트에서 날씨 데이터를 다운로드한다.
# - 사이트에 가입하고 로그인해야 다운로드할 수 있다.
# - https://data.kma.go.kr/data/grnd/selectAsosRltmList.do?pgmNo=36
# - csv파일 다운로드해서 사용
# - OBS_ASOS_MNH_~.csv 파일 이름을 'weather_data.csv'로 변경해서 사용하기

# %% [markdown]
# ---------

# %% [markdown]
# ## 데이터 가공 및 시각화하기

# %% [markdown]
# ### 4-1. 데이터 가공하기

# %% [markdown]
# #### 1. 다운로드된 데이터 불러오기

# %%
import pandas as pd

# OBS_ASOS_MNH_~.csv 파일명 데이터를 'weather_data.csv'로 변경하기 
#file = 'C:/python/gachon/2022_1_Statistics/data/weather_data.csv' 
file = 'data/weather_data.csv' 
df = pd.read_csv(file, encoding='CP949', engine='python')
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         지점 지점명          일시  평균기온(°C)  최고기온(°C)  최저기온(°C)  평균현지기압(hPa)  \
# 0       90  속초  1968-01-01      -0.7      11.4     -11.4       1018.2
# 1       90  속초  1968-02-01      -2.1       9.7      -9.9       1022.8
# 2       90  속초  1968-03-01       5.9      20.5      -3.2       1016.1
# 3       90  속초  1968-04-01      10.5      21.4       4.0       1019.4
# 4       90  속초  1968-05-01      14.6      24.5       9.3       1011.7
# ...    ...  ..         ...       ...       ...       ...          ...
# 54430  295  남해  2021-08-01      26.1      35.5      20.7       1003.2
# 54431  295  남해  2021-09-01      22.2      30.1      16.3       1008.1
# 54432  295  남해  2021-10-01      17.2      28.9       4.7       1015.3
# 54433  295  남해  2021-11-01      10.7      21.7       1.4       1014.2
# 54434  295  남해  2021-12-01       4.9      14.9      -8.0       1018.6
#
#        평균상대습도(%)  월합강수량(00~24h만)(mm)  평균풍속(m/s)  합계 일조시간(hr)  최심적설(cm)
# 0           47.0                 0.0        2.1        218.6       NaN
# 1           51.0                 3.3        2.2        236.5       1.8
# 2           57.0                 8.8        2.1        223.7       0.0
# 3           63.0                 6.9        2.0        255.7       NaN
# 4           74.0                49.1        2.2        187.8       NaN
# ...          ...                 ...        ...          ...       ...
# 54430       82.0               473.2        1.3        174.5       NaN
# 54431       82.0               164.6        1.5         95.2       NaN
# 54432       74.0                43.6        1.3        203.2       NaN
# 54433       67.0                53.5        1.6        178.9       NaN
# 54434       60.0                 2.4        1.8        184.0       NaN
#
# [54435 rows x 12 columns]

# %% [markdown]
# #### #데이터 요약

# %%
df.describe()
# Out:
#                  지점      평균기온(°C)      최고기온(°C)      최저기온(°C)   평균현지기압(hPa)  \
# count  54435.000000  53807.000000  54237.000000  54212.000000  51997.000000
# mean     186.670341     12.628870     24.317525      2.028092   1005.837291
# std       62.081035      9.152594      8.020697     10.765021     16.180945
# min       90.000000    -13.500000     -4.800000    -32.600000    911.800000
# 25%      133.000000      4.600000     17.900000     -6.500000   1001.200000
# 50%      170.000000     13.200000     25.800000      1.300000   1008.600000
# 75%      245.000000     20.900000     31.100000     11.400000   1015.900000
# max      295.000000     30.200000     41.000000     24.800000   1029.700000
#
#           평균상대습도(%)  월합강수량(00~24h만)(mm)     평균풍속(m/s)   합계 일조시간(hr)  \
# count  53241.000000        54150.000000  53282.000000  53055.000000
# mean      69.885971          110.341457      2.331489    188.699729
# std        9.838686          120.815806      1.294391     46.280604
# min        8.000000            0.000000     -0.400000      0.000000
# 25%       63.000000           30.700000      1.400000    158.700000
# 50%       71.000000           68.100000      2.000000    189.300000
# 75%       77.000000          145.900000      2.900000    219.300000
# max       99.000000         1364.200000     22.700000   1300.300000
#
#            최심적설(cm)
# count  11895.000000
# mean       8.191148
# std       14.853678
# min        0.000000
# 25%        1.500000
# 50%        4.300000
# 75%        9.000000
# max      293.600000

# %% [markdown]
# #### 2. 컬럼명 변경하기

# %%
df.columns
df.columns = ['지점', '지점명', '일시', '평균기온', '최고기온', '최저기온', '평균현지기압',
       '평균상대습도', '월합강수량', '평균풍속','일조시간', '최심적설']
df
# Out:
#         지점 지점명          일시  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  평균풍속  \
# 0       90  속초  1968-01-01  -0.7  11.4 -11.4  1018.2    47.0    0.0   2.1
# 1       90  속초  1968-02-01  -2.1   9.7  -9.9  1022.8    51.0    3.3   2.2
# 2       90  속초  1968-03-01   5.9  20.5  -3.2  1016.1    57.0    8.8   2.1
# 3       90  속초  1968-04-01  10.5  21.4   4.0  1019.4    63.0    6.9   2.0
# 4       90  속초  1968-05-01  14.6  24.5   9.3  1011.7    74.0   49.1   2.2
# ...    ...  ..         ...   ...   ...   ...     ...     ...    ...   ...
# 54430  295  남해  2021-08-01  26.1  35.5  20.7  1003.2    82.0  473.2   1.3
# 54431  295  남해  2021-09-01  22.2  30.1  16.3  1008.1    82.0  164.6   1.5
# 54432  295  남해  2021-10-01  17.2  28.9   4.7  1015.3    74.0   43.6   1.3
# 54433  295  남해  2021-11-01  10.7  21.7   1.4  1014.2    67.0   53.5   1.6
# 54434  295  남해  2021-12-01   4.9  14.9  -8.0  1018.6    60.0    2.4   1.8
#
#         일조시간  최심적설
# 0      218.6   NaN
# 1      236.5   1.8
# 2      223.7   0.0
# 3      255.7   NaN
# 4      187.8   NaN
# ...      ...   ...
# 54430  174.5   NaN
# 54431   95.2   NaN
# 54432  203.2   NaN
# 54433  178.9   NaN
# 54434  184.0   NaN
#
# [54435 rows x 12 columns]

# %% [markdown]
# #### 3. 컬럼 추가하기
# DataFrame.insert(추가하고싶은위치,컬럼명,값, allow_duplicate=False)

# %%
df.insert(3,'신규',df['지점'])
df
# Out:
#         지점 지점명          일시   신규  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 0       90  속초  1968-01-01   90  -0.7  11.4 -11.4  1018.2    47.0    0.0
# 1       90  속초  1968-02-01   90  -2.1   9.7  -9.9  1022.8    51.0    3.3
# 2       90  속초  1968-03-01   90   5.9  20.5  -3.2  1016.1    57.0    8.8
# 3       90  속초  1968-04-01   90  10.5  21.4   4.0  1019.4    63.0    6.9
# 4       90  속초  1968-05-01   90  14.6  24.5   9.3  1011.7    74.0   49.1
# ...    ...  ..         ...  ...   ...   ...   ...     ...     ...    ...
# 54430  295  남해  2021-08-01  295  26.1  35.5  20.7  1003.2    82.0  473.2
# 54431  295  남해  2021-09-01  295  22.2  30.1  16.3  1008.1    82.0  164.6
# 54432  295  남해  2021-10-01  295  17.2  28.9   4.7  1015.3    74.0   43.6
# 54433  295  남해  2021-11-01  295  10.7  21.7   1.4  1014.2    67.0   53.5
# 54434  295  남해  2021-12-01  295   4.9  14.9  -8.0  1018.6    60.0    2.4
#
#        평균풍속   일조시간  최심적설
# 0       2.1  218.6   NaN
# 1       2.2  236.5   1.8
# 2       2.1  223.7   0.0
# 3       2.0  255.7   NaN
# 4       2.2  187.8   NaN
# ...     ...    ...   ...
# 54430   1.3  174.5   NaN
# 54431   1.5   95.2   NaN
# 54432   1.3  203.2   NaN
# 54433   1.6  178.9   NaN
# 54434   1.8  184.0   NaN
#
# [54435 rows x 13 columns]

# %%
# 년월 추가
df.insert(3,'년도',df['일시'].str[0:4])
df
# Out:
#         지점 지점명          일시    년도   신규  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  \
# 0       90  속초  1968-01-01  1968   90  -0.7  11.4 -11.4  1018.2    47.0
# 1       90  속초  1968-02-01  1968   90  -2.1   9.7  -9.9  1022.8    51.0
# 2       90  속초  1968-03-01  1968   90   5.9  20.5  -3.2  1016.1    57.0
# 3       90  속초  1968-04-01  1968   90  10.5  21.4   4.0  1019.4    63.0
# 4       90  속초  1968-05-01  1968   90  14.6  24.5   9.3  1011.7    74.0
# ...    ...  ..         ...   ...  ...   ...   ...   ...     ...     ...
# 54430  295  남해  2021-08-01  2021  295  26.1  35.5  20.7  1003.2    82.0
# 54431  295  남해  2021-09-01  2021  295  22.2  30.1  16.3  1008.1    82.0
# 54432  295  남해  2021-10-01  2021  295  17.2  28.9   4.7  1015.3    74.0
# 54433  295  남해  2021-11-01  2021  295  10.7  21.7   1.4  1014.2    67.0
# 54434  295  남해  2021-12-01  2021  295   4.9  14.9  -8.0  1018.6    60.0
#
#        월합강수량  평균풍속   일조시간  최심적설
# 0        0.0   2.1  218.6   NaN
# 1        3.3   2.2  236.5   1.8
# 2        8.8   2.1  223.7   0.0
# 3        6.9   2.0  255.7   NaN
# 4       49.1   2.2  187.8   NaN
# ...      ...   ...    ...   ...
# 54430  473.2   1.3  174.5   NaN
# 54431  164.6   1.5   95.2   NaN
# 54432   43.6   1.3  203.2   NaN
# 54433   53.5   1.6  178.9   NaN
# 54434    2.4   1.8  184.0   NaN
#
# [54435 rows x 14 columns]

# %% [markdown]
# #### 4. 컬럼 삭제

# %%
df.drop('신규', axis=1, inplace=True)
df
# Out:
#         지점 지점명          일시    년도  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 0       90  속초  1968-01-01  1968  -0.7  11.4 -11.4  1018.2    47.0    0.0
# 1       90  속초  1968-02-01  1968  -2.1   9.7  -9.9  1022.8    51.0    3.3
# 2       90  속초  1968-03-01  1968   5.9  20.5  -3.2  1016.1    57.0    8.8
# 3       90  속초  1968-04-01  1968  10.5  21.4   4.0  1019.4    63.0    6.9
# 4       90  속초  1968-05-01  1968  14.6  24.5   9.3  1011.7    74.0   49.1
# ...    ...  ..         ...   ...   ...   ...   ...     ...     ...    ...
# 54430  295  남해  2021-08-01  2021  26.1  35.5  20.7  1003.2    82.0  473.2
# 54431  295  남해  2021-09-01  2021  22.2  30.1  16.3  1008.1    82.0  164.6
# 54432  295  남해  2021-10-01  2021  17.2  28.9   4.7  1015.3    74.0   43.6
# 54433  295  남해  2021-11-01  2021  10.7  21.7   1.4  1014.2    67.0   53.5
# 54434  295  남해  2021-12-01  2021   4.9  14.9  -8.0  1018.6    60.0    2.4
#
#        평균풍속   일조시간  최심적설
# 0       2.1  218.6   NaN
# 1       2.2  236.5   1.8
# 2       2.1  223.7   0.0
# 3       2.0  255.7   NaN
# 4       2.2  187.8   NaN
# ...     ...    ...   ...
# 54430   1.3  174.5   NaN
# 54431   1.5   95.2   NaN
# 54432   1.3  203.2   NaN
# 54433   1.6  178.9   NaN
# 54434   1.8  184.0   NaN
#
# [54435 rows x 13 columns]

# %% [markdown]
# #### 5. 특정 조건 검색

# %%
print( len( set(df['지점명']) ) )
print( set( df['지점명'] ) )
# Out:
# 102
# {'홍성', '진도군', '해남', '영덕', '남해', '철원', '부산', '양평', '서울', '대관령', '울진', '영광군', '산청', '서귀포', '춘천', '성산포', '합천', '진도(첨찰산)', '북춘천', '부여', '보령', '완도', '성산', '밀양', '김해시', '무안', '창원', '대구(기)', '천안', '강릉', '고창군', '북창원', '전주', '문경', '북강릉', '인천', '추풍령', '안동', '영주', '광주', '포항', '여수', '강화', '삼척', '양산시', '영월', '진주', '속초', '보은', '목포', '상주', '대구', '세종', '강진군', '봉화', '울산', '충주', '의성', '주암', '이천', '거창', '동두천', '인제', '청주', '광양시', '홍천', '의령군', '경주시', '함양군', '임실', '고산', '울릉도', '흑산도', '고흥', '군산', '제천', '고창', '관악산', '수원', '정읍', '백령도', '대전', '순창군', '보성군', '청송군', '태백', '장수', '서산', '통영', '금산', '원주', '파주', '순천', '거제', '정선군', '장흥', '동해', '남원', '부안', '제주', '구미', '영천'}

# %% [markdown]
# #### #지점명 '제주' 데이터

# %%
df.query(" 지점명 == '제주' ")

df.iloc[ df.index[ df['지점명'] == '제주' ] ]
# Out:
#         지점 지점명          일시    년도  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 27788  184  제주  1923-05-01  1923  16.5  27.0   8.3     NaN    82.0   70.7
# 27789  184  제주  1923-06-01  1923  19.7  31.2  10.4     NaN    82.0  385.3
# 27790  184  제주  1923-07-01  1923  23.6  33.0  17.1     NaN    86.0  359.5
# 27791  184  제주  1923-08-01  1923  26.7  34.6  20.2     NaN    77.0   92.2
# 27792  184  제주  1923-09-01  1923  22.1  30.4  13.4     NaN    78.0  145.0
# ...    ...  ..         ...   ...   ...   ...   ...     ...     ...    ...
# 28967  184  제주  2021-08-01  2021  27.3  33.8  22.2  1006.0    79.0  227.8
# 28968  184  제주  2021-09-01  2021  24.9  33.3  19.0  1010.0    84.0  493.1
# 28969  184  제주  2021-10-01  2021  20.1  31.8   9.0  1018.4    73.0   32.1
# 28970  184  제주  2021-11-01  2021  14.0  23.2   7.0  1018.4    66.0   63.8
# 28971  184  제주  2021-12-01  2021   8.9  17.4  -0.5  1023.2    67.0   31.4
#
#        평균풍속   일조시간  최심적설
# 27788   5.2  200.4   NaN
# 27789   5.1  227.3   NaN
# 27790   5.9  218.8   NaN
# 27791   6.6  301.7   NaN
# 27792   7.0  224.4   NaN
# ...     ...    ...   ...
# 28967   2.5  170.5   NaN
# 28968   3.4  129.3   NaN
# 28969   2.9  193.9   NaN
# 28970   3.7  151.2   NaN
# 28971   4.2   85.9   4.4
#
# [1184 rows x 13 columns]

# %% [markdown]
# #### #최초 측정월, 마지막 측정월

# %%
# 측정월 최소, 최대 
print ( min(df['일시']) )
print ( df['일시'].min() )
print ( max(df['일시']) )
print ( df['일시'].max() )
# Out:
# 1904-04-01
# 1904-04-01
# 2021-12-01
# 2021-12-01

# %%
# 측정 최초월('1904-04')의 데이터
df.query(" 일시 == '1904-04' ")

df.query(f" 일시 == '{df['일시'].min()}' ")

df.iloc[ df.index[ df['일시'] == df['일시'].min() ] ]
# Out:
#         지점 지점명          일시    년도  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 6369   112  인천  1904-04-01  1904   NaN  19.2   6.4     NaN     NaN  104.9
# 21791  159  부산  1904-04-01  1904   NaN  21.4   4.7     NaN     NaN  172.9
# 23944  165  목포  1904-04-01  1904   NaN  20.2   NaN     NaN     NaN   34.7
#
#        평균풍속  일조시간  최심적설
# 6369    NaN   NaN   NaN
# 21791   NaN   NaN   NaN
# 23944   NaN   NaN   NaN

# %% [markdown]
# ### [실습]: 가장 더웠던 날짜와 온도는?

# %%
field = '최고기온'
wmax = df[field].max()
cond = f" {field} >= {wmax}"
print(wmax, cond)
df.query(cond)
df.query("최고기온 >= 41.0")

# print(df[field].max(), f" {field} >= {df[field].max()}")
# df.query(f" {field} >= { df[field].max() }")
# Out:
# 41.0  최고기온 >= 41.0
#         지점 지점명          일시    년도  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 34762  212  홍천  2018-08-01  2018  27.2  41.0  15.8   991.7    73.0  300.6
#
#        평균풍속   일조시간  최심적설
# 34762   1.4  234.4   NaN

# %% [markdown]
# ### [실습]: 가장 추웠던 날짜와 온도는?

# %%
field = '최저기온'
# wmin = df[field].min()
# cond = f" {field} <= {wmin}"
# df.query(cond)
# df.query("최저기온 <= -32.6")

print(df[field].min(), f" {field} >= {df[field].min()}")
df.query(f" {field} <= { df[field].min() }")
# Out:
# -32.6  최저기온 >= -32.6
#         지점 지점명          일시    년도  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 32495  202  양평  1981-01-01  1981 -13.5   1.2 -32.6  1022.4    69.0   17.5
#
#        평균풍속   일조시간  최심적설
# 32495   0.8  194.9  21.0

# %% [markdown]
# ###  [실습] : '제주'에서 가장 더웠던 날짜와 기온?

# %%
wmax = df.query(" 지점명 == '제주' ")['최고기온'].max()
df.query(f" 지점명 == '제주' and 최고기온 >= { wmax }")
# Out:
#         지점 지점명          일시    년도  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 28018  184  제주  1942-07-01  1942  27.0  37.5  17.8  1008.8    78.0   15.5
#
#        평균풍속   일조시간  최심적설
# 28018   3.0  347.2   NaN

# %% [markdown]
# ###  [실습] : '제주'에서 가장 추웠던 날짜와 기온은?

# %%
wmin = df.query(" 지점명 == '제주' ")['최저기온'].min() 
df.query(f" 지점명 == '제주' and 최저기온 <= { wmin  } ")
# Out:
#         지점 지점명          일시    년도  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  \
# 28433  184  제주  1977-02-01  1977   4.0  17.5  -6.0  1021.8    71.0   36.1
#
#        평균풍속  일조시간  최심적설
# 28433   5.2  89.3  18.1

# %% [markdown]
# --------

# %% [markdown]
# #### #그룹핑: 지점별 평균 기온

# %%
df.groupby(['지점명'], as_index=False).mean()
# Out:
#      지점명     지점       평균기온       최고기온      최저기온       평균현지기압     평균상대습도  \
# 0     강릉  105.0  12.551719  24.977913  2.261995  1013.760566  64.095420
# 1    강진군  259.0  13.688194  24.944521  3.445890  1015.421528  71.937500
# 2     강화  201.0  11.123810  22.437521  0.131993  1012.365986  70.301020
# 3     거제  294.0  14.186565  24.367114  4.575839  1013.037585  66.811224
# 4     거창  284.0  11.765476  25.072027 -0.346231   989.892794  70.064626
# ..   ...    ...        ...        ...       ...          ...        ...
# 97    합천  285.0  13.025680  26.040986  1.271939  1012.804770  68.022109
# 98    해남  261.0  13.407993  24.497351  2.577649  1013.453571  74.362245
# 99    홍성  177.0  12.627027  24.409459  1.475676  1013.752703  75.824324
# 100   홍천  212.0  10.532653  24.225168 -2.148490   999.974660  69.629252
# 101  흑산도  169.0  13.564000  22.061333  7.189667  1006.992333  78.663333
#
#           월합강수량      평균풍속        일조시간       최심적설
# 0    112.119131  2.919847  190.108672  17.191809
# 1    119.152055  2.417931  184.370548   7.450000
# 2    107.645813  1.738095  203.184812   4.911034
# 3    155.911092  1.792687  197.441468   3.147727
# 4    106.362395  1.339116  199.919283   5.467901
# ..          ...       ...         ...        ...
# 97   107.293186  1.216014  195.761263   3.942857
# 98   109.593950  2.107496  194.226451   4.406107
# 99    95.486486  1.505405  202.408108   4.771429
# 100  109.192904  0.997615  188.059044   6.472611
# 101   93.252000  5.383667  163.708667   3.796970
#
# [102 rows x 11 columns]

# %%
df.groupby(['지점명'], as_index=False).count()
# Out:
#      지점명    지점    일시    년도  평균기온  최고기온  최저기온  평균현지기압  평균상대습도  월합강수량  평균풍속  \
# 0     강릉  1313  1313  1313  1309  1313  1313    1131    1310   1312  1310
# 1    강진군   146   146   146   144   146   146     144     144    146   145
# 2     강화   609   609   609   588   597   597     588     588    609   588
# 3     거제   597   597   597   588   596   596     588     588    586   588
# 4     거창   598   598   598   588   597   597     569     588    593   588
# ..   ...   ...   ...   ...   ...   ...   ...     ...     ...    ...   ...
# 97    합천   591   591   591   588   588   588     587     588    587   587
# 98    해남   606   606   606   588   604   604     588     588    595   587
# 99    홍성    74    74    74    74    74    74      74      74     74    74
# 100   홍천   606   606   606   588   596   596     588     588    606   587
# 101  흑산도   300   300   300   300   300   300     300     300    300   300
#
#      일조시간  최심적설
# 0    1303   293
# 1     146    14
# 2     586   145
# 3     586    44
# 4     586   162
# ..    ...   ...
# 97    586    91
# 98    586   131
# 99     74    14
# 100   586   157
# 101   300    66
#
# [102 rows x 13 columns]

# %% [markdown]
# ### [실습] : 지점별 평균기온

# %% [markdown]
# #### 방법1: groupby 이용

# %%
# grouped =df['평균기온'].groupby(df['지점명'])
# grouped.mean()

df['평균기온'].groupby(df['지점명']).mean()
# Out:
# 지점명
# 강릉     12.551719
# 강진군    13.688194
# 강화     11.123810
# 거제     14.186565
# 거창     11.765476
#          ...
# 합천     13.025680
# 해남     13.407993
# 홍성     12.627027
# 홍천     10.532653
# 흑산도    13.564000
# Name: 평균기온, Length: 102, dtype: float64

# %% [markdown]
# ####  방법2: agg() 사용

# %% [markdown]
# #### 컬럼 1개: 지점명별 그룹

# %%
df.groupby('지점명')['평균기온'].agg(**{'평균기온':'mean'})

#df.groupby('지점명')['평균기온'].agg(**{'mean_temp':'mean'}).reset_index()
# Out:
#           평균기온
# 지점명
# 강릉   12.551719
# 강진군  13.688194
# 강화   11.123810
# 거제   14.186565
# 거창   11.765476
# ..         ...
# 합천   13.025680
# 해남   13.407993
# 홍성   12.627027
# 홍천   10.532653
# 흑산도  13.564000
#
# [102 rows x 1 columns]

# %% [markdown]
# #### 컬럼 2개: 지점명, 년도별 그룹

# %%
df.groupby(['지점명','년도'])['평균기온'].agg(**{'평균기온':'mean'})
#df.groupby(['지점명','년도'])['평균기온'].agg(**{'평균기온':'mean'}).reset_index()
# Out:
#                평균기온
# 지점명 년도
# 강릉  1911        NaN
#     1912  11.733333
#     1913  11.683333
#     1914  13.175000
#     1915  12.091667
# ...             ...
# 흑산도 2017  13.491667
#     2018  13.825000
#     2019  14.066667
#     2020  14.100000
#     2021  15.258333
#
# [4560 rows x 1 columns]

# %% [markdown]
# ### [실습] : 지점별 최고기온?

# %%
#df.groupby('지점명')['최고기온'].agg(**{'최고기온':'max'}).reset_index()
#df.groupby('지점명')['최고기온'].agg(**{'최고기온':'max'})

df2 = df.groupby('지점명')['최고기온'].agg(**{'최고기온':'max'})

# %% [markdown]
# ### [실습] : 지점별 년도별 최대강수량?

# %%
df.groupby(['지점명','년도'])['최고기온'].agg(**{'일최다강수량':'max'})
# Out:
#           일최다강수량
# 지점명 년도
# 강릉  1911    26.2
#     1912    36.3
#     1913    33.9
#     1914    37.3
#     1915    36.3
# ...          ...
# 흑산도 2017    33.7
#     2018    34.9
#     2019    29.9
#     2020    33.1
#     2021    32.8
#
# [4560 rows x 1 columns]

# %% [markdown]
# #### #한 행씩 불러오기
# !!![주의]!!! 데이터가 많을 경우 실행하지 않도록

# %%
# 한 행씩 불러오기  ---->
for i, row in df.iterrows():
    #print(i, row)
    print(i, row['지점명'], row['최고기온'])
# Out:
# 0 속초 11.4
# 1 속초 9.7
# 2 속초 20.5
# 3 속초 21.4
# 4 속초 24.5
# 5 속초 29.2
# 6 속초 35.8
# 7 속초 31.9
# 8 속초 27.1
# 9 속초 23.3
# 10 속초 20.8
# 11 속초 16.7
# 12 속초 10.4
# 13 속초 13.5
# 14 속초 21.6
# 15 속초 26.6
# 16 속초 28.4
# 17 속초 29.9
# 18 속초 32.4
# 19 속초 33.8
# 20 속초 29.1
# 21 속초 25.4
# 22 속초 20.4
# 23 속초 12.8
# 24 속초 9.6
# 25 속초 16.6
# 26 속초 19.4
# 27 속초 21.0
# 28 속초 30.0
# 29 속초 27.8
# 30 속초 35.2
# 31 속초 32.4
# 32 속초 29.9
# 33 속초 23.4
# 34 속초 20.5
# 35 속초 16.6
# 36 속초 10.4
# 37 속초 7.9
# 38 속초 23.0
# 39 속초 26.4
# 40 속초 31.3
# 41 속초 30.5
# 42 속초 34.5
# 43 속초 35.4
# 44 속초 25.2
# 45 속초 23.4
# 46 속초 23.9
# 47 속초 13.0
# 48 속초 9.8
# 49 속초 4.8
# 50 속초 20.2
# 51 속초 28.4
# 52 속초 27.8
# 53 속초 33.6
# 54 속초 34.4
# 55 속초 34.2
# 56 속초 25.6
# 57 속초 25.0
# 58 속초 16.9
# 59 속초 14.7
# 60 속초 7.8
# 61 속초 12.5
# 62 속초 23.6
# 63 속초 28.2
# 64 속초 28.2
# 65 속초 30.8
# 66 속초 34.6
# 67 속초 34.6
# 68 속초 25.8
# 69 속초 26.0
# 70 속초 18.8
# 71 속초 12.4
# 72 속초 10.0
# 73 속초 11.3
# 74 속초 14.3
# 75 속초 22.6
# 76 속초 30.4
# 77 속초 33.2
# 78 속초 27.3
# 79 속초 33.8
# 80 속초 30.4
# 81 속초 24.9
# 82 속초 19.0
# 83 속초 8.6
# 84 속초 10.2
# 85 속초 11.1
# 86 속초 16.5
# 87 속초 21.9
# 88 속초 27.7
# 89 속초 30.4
# 90 속초 34.1
# 91 속초 33.7
# 92 속초 29.2
# 93 속초 23.1
# 94 속초 17.0
# 95 속초 16.4
# 96 속초 11.7
# 97 속초 11.5
# 98 속초 17.1
# 99 속초 24.8
# 100 속초 27.5
# 101 속초 26.6
# 102 속초 33.2
# 103 속초 33.3
# 104 속초 29.0
# 105 속초 21.2
# 106 속초 19.9
# 107 속초 12.8
# 108 속초 7.0
# 109 속초 18.7
# 110 속초 21.0
# 111 속초 25.7
# 112 속초 30.9
# 113 속초 28.1
# 114 속초 34.4
# 115 속초 34.1
# 116 속초 30.3
# 117 속초 26.1
# 118 속초 17.3
# 119 속초 13.7
# 120 속초 9.7
# 121 속초 11.1
# 122 속초 19.9
# 123 속초 25.8
# 124 속초 27.7
# 125 속초 32.8
# 126 속초 34.7
# 127 속초 34.7
# 128 속초 29.7
# 129 속초 28.8
# 130 속초 19.4
# 131 속초 15.1
# 132 속초 14.8
# 133 속초 16.4
# 134 속초 16.7
# 135 속초 23.4
# 136 속초 31.5
# 137 속초 31.5
# 138 속초 34.7
# 139 속초 34.6
# 140 속초 27.8
# 141 속초 26.8
# 142 속초 23.0
# 143 속초 14.5
# 144 속초 11.6
# 145 속초 13.9
# 146 속초 18.2
# 147 속초 23.8
# 148 속초 31.9
# 149 속초 32.8
# 150 속초 31.1
# 151 속초 30.6
# 152 속초 27.6
# 153 속초 26.2
# 154 속초 20.3
# 155 속초 13.8
# 156 속초 7.0
# 157 속초 12.4
# 158 속초 18.9
# 159 속초 28.4
# 160 속초 30.6
# 161 속초 29.8
# 162 속초 35.8
# 163 속초 33.9
# 164 속초 27.8
# 165 속초 25.8
# 166 속초 16.1
# 167 속초 11.5
# 168 속초 13.1
# 169 속초 13.9
# 170 속초 16.9
# 171 속초 22.4
# 172 속초 29.6
# 173 속초 32.6
# 174 속초 31.2
# 175 속초 31.7
# 176 속초 29.6
# 177 속초 28.9
# 178 속초 19.1
# 179 속초 11.8
# 180 속초 13.7
# 181 속초 9.6
# 182 속초 13.1
# 183 속초 29.1
# 184 속초 30.1
# 185 속초 33.4
# 186 속초 34.7
# 187 속초 35.8
# 188 속초 29.7
# 189 속초 26.7
# 190 속초 20.4
# 191 속초 13.5
# 192 속초 5.5
# 193 속초 6.5
# 194 속초 17.7
# 195 속초 19.0
# 196 속초 26.7
# 197 속초 30.0
# 198 속초 32.1
# 199 속초 35.6
# 200 속초 26.2
# 201 속초 24.5
# 202 속초 22.8
# 203 속초 13.8
# 204 속초 7.4
# 205 속초 13.2
# 206 속초 13.0
# 207 속초 28.1
# 208 속초 26.2
# 209 속초 27.3
# 210 속초 34.7
# 211 속초 33.9
# 212 속초 29.6
# 213 속초 26.7
# 214 속초 18.3
# 215 속초 11.6
# 216 속초 9.7
# 217 속초 7.4
# 218 속초 16.4
# 219 속초 22.2
# 220 속초 29.3
# 221 속초 32.7
# 222 속초 32.9
# 223 속초 32.2
# 224 속초 26.9
# 225 속초 22.8
# 226 속초 18.8
# 227 속초 13.6
# 228 속초 13.4
# 229 속초 17.7
# 230 속초 14.0
# 231 속초 26.8
# 232 속초 29.6
# 233 속초 33.8
# 234 속초 31.9
# 235 속초 31.2
# 236 속초 29.4
# 237 속초 29.0
# 238 속초 18.9
# 239 속초 17.8
# 240 속초 11.8
# 241 속초 11.4
# 242 속초 17.2
# 243 속초 27.5
# 244 속초 31.7
# 245 속초 29.0
# 246 속초 33.2
# 247 속초 32.9
# 248 속초 26.3
# 249 속초 25.6
# 250 속초 19.2
# 251 속초 15.8
# 252 속초 8.5
# 253 속초 14.4
# 254 속초 17.9
# 255 속초 24.8
# 256 속초 31.8
# 257 속초 29.9
# 258 속초 33.6
# 259 속초 32.7
# 260 속초 27.5
# 261 속초 25.0
# 262 속초 18.2
# 263 속초 17.3
# 264 속초 10.7
# 265 속초 11.3
# 266 속초 17.9
# 267 속초 21.9
# 268 속초 30.0
# 269 속초 32.2
# 270 속초 33.2
# 271 속초 32.8
# 272 속초 28.3
# 273 속초 24.2
# 274 속초 21.9
# 275 속초 16.1
# 276 속초 8.5
# 277 속초 9.1
# 278 속초 18.1
# 279 속초 23.2
# 280 속초 29.6
# 281 속초 32.1
# 282 속초 32.4
# 283 속초 31.9
# 284 속초 28.4
# 285 속초 29.0
# 286 속초 19.4
# 287 속초 17.2
# 288 속초 12.3
# 289 속초 18.3
# 290 속초 18.8
# 291 속초 27.7
# 292 속초 28.1
# 293 속초 28.3
# 294 속초 35.7
# 295 속초 30.8
# 296 속초 31.7
# 297 속초 23.4
# 298 속초 18.7
# 299 속초 14.9
# 300 속초 10.6
# 301 속초 19.1
# 302 속초 15.6
# 303 속초 26.9
# 304 속초 30.6
# 305 속초 30.1
# 306 속초 28.6
# 307 속초 29.6
# 308 속초 28.2
# 309 속초 27.6
# 310 속초 23.0
# 311 속초 11.9
# 312 속초 11.9
# 313 속초 12.1
# 314 속초 14.8
# 315 속초 23.5
# 316 속초 29.9
# 317 속초 29.4
# 318 속초 35.3
# 319 속초 34.8
# 320 속초 30.9
# 321 속초 24.7
# 322 속초 22.3
# 323 속초 16.6
# 324 속초 12.5
# 325 속초 12.7
# 326 속초 17.0
# 327 속초 23.1
# 328 속초 28.1
# 329 속초 27.1
# 330 속초 34.3
# 331 속초 34.3
# 332 속초 31.6
# 333 속초 25.1
# 334 속초 21.8
# 335 속초 10.6
# 336 속초 9.3
# 337 속초 17.4
# 338 속초 16.5
# 339 속초 31.4
# 340 속초 31.2
# 341 속초 29.9
# 342 속초 34.6
# 343 속초 33.1
# 344 속초 29.2
# 345 속초 25.2
# 346 속초 21.2
# 347 속초 15.1
# 348 속초 9.7
# 349 속초 13.7
# 350 속초 20.9
# 351 속초 26.4
# 352 속초 27.4
# 353 속초 31.7
# 354 속초 33.3
# 355 속초 35.9
# 356 속초 33.6
# 357 속초 27.0
# 358 속초 20.2
# 359 속초 14.7
# 360 속초 10.3
# 361 속초 14.6
# 362 속초 24.3
# 363 속초 32.1
# 364 속초 29.0
# 365 속초 30.6
# 366 속초 31.3
# 367 속초 31.4
# 368 속초 29.2
# 369 속초 23.7
# 370 속초 23.9
# 371 속초 15.2
# 372 속초 11.9
# 373 속초 14.4
# 374 속초 17.3
# 375 속초 25.6
# 376 속초 29.5
# 377 속초 32.5
# 378 속초 33.3
# 379 속초 30.7
# 380 속초 32.0
# 381 속초 25.0
# 382 속초 19.2
# 383 속초 12.4
# 384 속초 9.9
# 385 속초 9.2
# 386 속초 18.5
# 387 속초 24.1
# 388 속초 30.5
# 389 속초 33.3
# 390 속초 33.6
# 391 속초 33.7
# 392 속초 32.0
# 393 속초 23.0
# 394 속초 19.9
# 395 속초 14.5
# 396 속초 6.2
# 397 속초 16.2
# 398 속초 19.9
# 399 속초 25.2
# 400 속초 31.2
# 401 속초 34.2
# 402 속초 31.3
# 403 속초 30.9
# 404 속초 29.3
# 405 속초 24.9
# 406 속초 20.2
# 407 속초 10.1
# 408 속초 15.8
# 409 속초 14.2
# 410 속초 20.3
# 411 속초 29.6
# 412 속초 28.4
# 413 속초 33.1
# 414 속초 36.6
# 415 속초 34.6
# 416 속초 34.1
# 417 속초 24.5
# 418 속초 21.0
# 419 속초 17.6
# 420 속초 11.3
# 421 속초 11.1
# 422 속초 19.9
# 423 속초 26.6
# 424 속초 27.7
# 425 속초 31.2
# 426 속초 27.6
# 427 속초 33.2
# 428 속초 28.5
# 429 속초 23.0
# 430 속초 23.3
# 431 속초 12.8
# 432 속초 9.6
# 433 속초 19.1
# 434 속초 22.9
# 435 속초 29.0
# 436 속초 29.2
# 437 속초 31.3
# 438 속초 37.1
# 439 속초 34.3
# 440 속초 30.5
# 441 속초 25.1
# 442 속초 20.1
# 443 속초 17.8
# 444 속초 9.8
# 445 속초 7.3
# 446 속초 18.1
# 447 속초 32.0
# 448 속초 29.7
# 449 속초 33.2
# 450 속초 34.4
# 451 속초 36.0
# 452 속초 32.2
# 453 속초 27.7
# 454 속초 22.4
# 455 속초 11.6
# 456 속초 8.3
# 457 속초 16.1
# 458 속초 18.9
# 459 속초 25.6
# 460 속초 29.8
# 461 속초 30.8
# 462 속초 32.6
# 463 속초 33.0
# 464 속초 27.4
# 465 속초 29.3
# 466 속초 20.6
# 467 속초 11.3
# 468 속초 8.9
# 469 속초 18.8
# 470 속초 19.0
# 471 속초 27.6
# 472 속초 30.3
# 473 속초 30.5
# 474 속초 34.5
# 475 속초 35.3
# 476 속초 30.0
# 477 속초 27.8
# 478 속초 19.9
# 479 속초 11.8
# 480 속초 10.7
# 481 속초 12.8
# 482 속초 17.7
# 483 속초 29.5
# 484 속초 29.8
# 485 속초 31.2
# 486 속초 34.7
# 487 속초 33.0
# 488 속초 29.8
# 489 속초 28.8
# 490 속초 22.3
# 491 속초 14.5
# 492 속초 10.5
# 493 속초 12.8
# 494 속초 25.7
# 495 속초 29.3
# 496 속초 30.3
# 497 속초 32.4
# 498 속초 32.0
# 499 속초 32.1
# 500 속초 29.0
# 501 속초 26.2
# 502 속초 23.2
# 503 속초 11.3
# 504 속초 12.6
# 505 속초 14.2
# 506 속초 13.2
# 507 속초 20.3
# 508 속초 30.9
# 509 속초 29.2
# 510 속초 35.1
# 511 속초 35.1
# 512 속초 31.1
# 513 속초 24.4
# 514 속초 21.1
# 515 속초 17.7
# 516 속초 6.3
# 517 속초 15.1
# 518 속초 18.7
# 519 속초 24.6
# 520 속초 26.6
# 521 속초 35.3
# 522 속초 30.7
# 523 속초 35.7
# 524 속초 29.0
# 525 속초 26.4
# 526 속초 19.3
# 527 속초 9.7
# 528 속초 6.4
# 529 속초 11.0
# 530 속초 19.4
# 531 속초 24.3
# 532 속초 27.8
# 533 속초 29.0
# 534 속초 34.7
# 535 속초 31.3
# 536 속초 29.3
# 537 속초 24.0
# 538 속초 16.9
# 539 속초 11.2
# 540 속초 10.0
# 541 속초 13.5
# 542 속초 18.8
# 543 속초 22.1
# 544 속초 29.0
# 545 속초 29.4
# 546 속초 33.6
# 547 속초 35.8
# 548 속초 29.2
# 549 속초 26.0
# 550 속초 19.9
# 551 속초 13.0
# 552 속초 12.6
# 553 속초 16.7
# 554 속초 26.9
# 555 속초 27.0
# 556 속초 32.5
# 557 속초 32.8
# 558 속초 34.6
# 559 속초 33.3
# 560 속초 31.0
# 561 속초 24.6
# 562 속초 19.5
# 563 속초 11.7
# 564 속초 12.2
# 565 속초 14.5
# 566 속초 21.4
# 567 속초 29.8
# 568 속초 32.6
# 569 속초 30.1
# 570 속초 35.4
# 571 속초 33.0
# 572 속초 27.1
# 573 속초 26.2
# 574 속초 21.7
# 575 속초 10.9
# 576 속초 11.5
# 577 속초 10.3
# 578 속초 21.5
# 579 속초 29.3
# 580 속초 29.0
# 581 속초 30.5
# 582 속초 31.9
# 583 속초 35.9
# 584 속초 28.6
# 585 속초 24.2
# 586 속초 20.8
# 587 속초 14.1
# 588 속초 11.3
# 589 속초 14.7
# 590 속초 18.5
# 591 속초 30.8
# 592 속초 34.3
# 593 속초 29.7
# 594 속초 34.9
# 595 속초 32.4
# 596 속초 28.4
# 597 속초 25.0
# 598 속초 20.4
# 599 속초 11.4
# 600 속초 11.9
# 601 속초 10.5
# 602 속초 24.7
# 603 속초 32.5
# 604 속초 29.4
# 605 속초 33.9
# 606 속초 35.4
# 607 속초 38.7
# 608 속초 29.0
# 609 속초 23.8
# 610 속초 19.2
# 611 속초 12.7
# 612 속초 12.8
# 613 속초 15.7
# 614 속초 21.6
# 615 속초 25.9
# 616 속초 34.2
# 617 속초 30.2
# 618 속초 36.1
# 619 속초 35.6
# 620 속초 32.3
# 621 속초 25.0
# 622 속초 21.1
# 623 속초 14.4
# 624 속초 11.2
# 625 속초 16.1
# 626 속초 19.3
# 627 속초 24.5
# 628 속초 32.4
# 629 속초 33.2
# 630 속초 33.3
# 631 속초 35.1
# 632 속초 28.7
# 633 속초 23.7
# 634 속초 23.1
# 635 속초 11.2
# 636 속초 9.7
# 637 속초 17.8
# 638 속초 18.9
# 639 속초 23.8
# 640 속초 29.8
# 641 속초 30.0
# 642 속초 33.2
# 643 속초 33.8
# 644 속초 28.8
# 645 속초 27.5
# 646 속초 20.1
# 647 속초 13.9
# 648 북춘천 29.0
# 649 북춘천 19.5
# 650 북춘천 10.2
# 651 북춘천 11.6
# 652 북춘천 12.2
# 653 북춘천 19.0
# 654 북춘천 29.1
# 655 북춘천 30.7
# 656 북춘천 35.0
# 657 북춘천 34.9
# 658 북춘천 37.5
# 659 북춘천 30.5
# 660 북춘천 26.9
# 661 북춘천 18.8
# 662 북춘천 8.6
# 663 북춘천 8.6
# 664 북춘천 10.4
# 665 북춘천 23.4
# 666 북춘천 29.2
# 667 북춘천 31.0
# 668 북춘천 34.5
# 669 북춘천 37.6
# 670 북춘천 40.6
# 671 북춘천 29.5
# 672 북춘천 25.0
# 673 북춘천 19.3
# 674 북춘천 12.0
# 675 북춘천 8.3
# 676 북춘천 13.4
# 677 북춘천 18.3
# 678 북춘천 28.3
# 679 북춘천 33.3
# 680 북춘천 33.1
# 681 북춘천 36.2
# 682 북춘천 36.5
# 683 북춘천 31.6
# 684 북춘천 29.9
# 685 북춘천 20.3
# 686 북춘천 10.5
# 687 북춘천 10.9
# 688 북춘천 15.5
# 689 북춘천 21.0
# 690 북춘천 24.6
# 691 북춘천 29.8
# 692 북춘천 35.8
# 693 북춘천 32.7
# 694 북춘천 35.4
# 695 북춘천 30.0
# 696 북춘천 23.7
# 697 북춘천 19.4
# 698 북춘천 9.9
# 699 북춘천 11.5
# 700 북춘천 19.7
# 701 북춘천 22.8
# 702 북춘천 29.2
# 703 북춘천 30.6
# 704 북춘천 32.3
# 705 북춘천 36.6
# 706 북춘천 34.4
# 707 북춘천 29.7
# 708 북춘천 28.2
# 709 북춘천 21.0
# 710 북춘천 11.4
# 711 철원 7.3
# 712 철원 10.8
# 713 철원 16.0
# 714 철원 26.5
# 715 철원 32.4
# 716 철원 32.8
# 717 철원 33.4
# 718 철원 36.9
# 719 철원 30.8
# 720 철원 24.8
# 721 철원 16.6
# 722 철원 14.4
# 723 철원 8.2
# 724 철원 12.3
# 725 철원 16.0
# 726 철원 29.7
# 727 철원 30.6
# 728 철원 32.2
# 729 철원 32.4
# 730 철원 34.6
# 731 철원 29.5
# 732 철원 22.8
# 733 철원 16.4
# 734 철원 12.3
# 735 철원 6.2
# 736 철원 10.4
# 737 철원 17.6
# 738 철원 27.0
# 739 철원 25.3
# 740 철원 28.7
# 741 철원 32.6
# 742 철원 34.1
# 743 철원 29.9
# 744 철원 26.1
# 745 철원 19.8
# 746 철원 12.0
# 747 철원 7.1
# 748 철원 8.4
# 749 철원 19.5
# 750 철원 24.5
# 751 철원 30.2
# 752 철원 30.3
# 753 철원 31.0
# 754 철원 32.8
# 755 철원 29.9
# 756 철원 25.4
# 757 철원 17.5
# 758 철원 11.5
# 759 철원 4.4
# 760 철원 16.0
# 761 철원 19.8
# 762 철원 23.8
# 763 철원 29.2
# 764 철원 30.2
# 765 철원 32.4
# 766 철원 33.0
# 767 철원 29.9
# 768 철원 24.7
# 769 철원 16.3
# 770 철원 13.0
# 771 철원 7.7
# 772 철원 12.2
# 773 철원 17.8
# 774 철원 25.3
# 775 철원 30.6
# 776 철원 29.3
# 777 철원 30.6
# 778 철원 29.8
# 779 철원 28.9
# 780 철원 24.9
# 781 철원 19.6
# 782 철원 8.2
# 783 철원 8.5
# 784 철원 10.5
# 785 철원 18.5
# 786 철원 27.7
# 787 철원 26.0
# 788 철원 33.1
# 789 철원 35.4
# 790 철원 34.4
# 791 철원 29.4
# 792 철원 23.2
# 793 철원 19.2
# 794 철원 11.1
# 795 철원 8.6
# 796 철원 9.8
# 797 철원 16.5
# 798 철원 26.6
# 799 철원 26.7
# 800 철원 30.3
# 801 철원 32.6
# 802 철원 32.1
# 803 철원 27.9
# 804 철원 25.0
# 805 철원 17.1
# 806 철원 6.4
# 807 철원 8.4
# 808 철원 12.8
# 809 철원 17.3
# 810 철원 24.6
# 811 철원 31.0
# 812 철원 30.7
# 813 철원 32.2
# 814 철원 33.5
# 815 철원 29.7
# 816 철원 22.7
# 817 철원 18.6
# 818 철원 11.5
# 819 철원 6.0
# 820 철원 13.7
# 821 철원 19.2
# 822 철원 22.1
# 823 철원 26.9
# 824 철원 34.0
# 825 철원 34.6
# 826 철원 32.6
# 827 철원 30.1
# 828 철원 24.3
# 829 철원 18.3
# 830 철원 10.1
# 831 철원 5.3
# 832 철원 14.2
# 833 철원 19.0
# 834 철원 26.4
# 835 철원 29.7
# 836 철원 30.5
# 837 철원 31.6
# 838 철원 30.2
# 839 철원 33.7
# 840 철원 25.8
# 841 철원 19.2
# 842 철원 11.0
# 843 철원 10.3
# 844 철원 8.9
# 845 철원 16.4
# 846 철원 28.4
# 847 철원 27.2
# 848 철원 32.9
# 849 철원 32.8
# 850 철원 33.9
# 851 철원 31.5
# 852 철원 23.0
# 853 철원 17.4
# 854 철원 10.5
# 855 철원 7.9
# 856 철원 5.9
# 857 철원 18.2
# 858 철원 23.3
# 859 철원 29.6
# 860 철원 32.7
# 861 철원 33.6
# 862 철원 33.3
# 863 철원 31.2
# 864 철원 26.1
# 865 철원 21.0
# 866 철원 11.6
# 867 철원 5.3
# 868 철원 11.5
# 869 철원 20.6
# 870 철원 27.3
# 871 철원 31.4
# 872 철원 32.3
# 873 철원 32.7
# 874 철원 33.1
# 875 철원 30.7
# 876 철원 24.6
# 877 철원 15.7
# 878 철원 9.9
# 879 철원 10.1
# 880 철원 12.9
# 881 철원 19.4
# 882 철원 27.6
# 883 철원 26.4
# 884 철원 31.4
# 885 철원 34.4
# 886 철원 30.1
# 887 철원 29.2
# 888 철원 23.6
# 889 철원 16.1
# 890 철원 14.5
# 891 철원 6.1
# 892 철원 9.4
# 893 철원 20.3
# 894 철원 23.3
# 895 철원 28.9
# 896 철원 29.3
# 897 철원 30.2
# 898 철원 30.4
# 899 철원 26.2
# 900 철원 25.1
# 901 철원 19.8
# 902 철원 8.1
# 903 철원 6.3
# 904 철원 17.5
# 905 철원 18.7
# 906 철원 27.7
# 907 철원 25.2
# 908 철원 31.3
# 909 철원 32.6
# 910 철원 33.4
# 911 철원 28.9
# 912 철원 25.7
# 913 철원 20.2
# 914 철원 13.9
# 915 철원 7.2
# 916 철원 10.0
# 917 철원 16.7
# 918 철원 26.7
# 919 철원 29.0
# 920 철원 30.9
# 921 철원 33.8
# 922 철원 33.1
# 923 철원 29.7
# 924 철원 23.4
# 925 철원 21.7
# 926 철원 5.5
# 927 철원 7.6
# 928 철원 11.5
# 929 철원 15.9
# 930 철원 21.6
# 931 철원 28.4
# 932 철원 31.5
# 933 철원 29.9
# 934 철원 33.9
# 935 철원 29.4
# 936 철원 27.2
# 937 철원 19.6
# 938 철원 12.1
# 939 철원 8.6
# 940 철원 15.2
# 941 철원 16.4
# 942 철원 23.3
# 943 철원 28.8
# 944 철원 33.9
# 945 철원 30.3
# 946 철원 32.1
# 947 철원 30.7
# 948 철원 26.6
# 949 철원 19.1
# 950 철원 12.0
# 951 철원 5.5
# 952 철원 9.3
# 953 철원 19.1
# 954 철원 28.4
# 955 철원 28.9
# 956 철원 30.1
# 957 철원 33.3
# 958 철원 35.1
# 959 철원 30.7
# 960 철원 28.2
# 961 철원 18.8
# 962 철원 12.1
# 963 철원 9.9
# 964 철원 15.3
# 965 철원 21.9
# 966 철원 27.4
# 967 철원 30.5
# 968 철원 30.3
# 969 철원 31.2
# 970 철원 33.2
# 971 철원 28.7
# 972 철원 25.8
# 973 철원 20.0
# 974 철원 9.2
# 975 철원 7.0
# 976 철원 17.2
# 977 철원 14.2
# 978 철원 21.4
# 979 철원 28.6
# 980 철원 32.8
# 981 철원 32.1
# 982 철원 32.9
# 983 철원 31.1
# 984 철원 24.1
# 985 철원 16.7
# 986 철원 12.9
# 987 철원 3.6
# 988 철원 13.3
# 989 철원 18.1
# 990 철원 20.6
# 991 철원 30.0
# 992 철원 33.2
# 993 철원 32.3
# 994 철원 34.3
# 995 철원 30.1
# 996 철원 21.9
# 997 철원 24.0
# 998 철원 6.8
# 999 철원 7.1
# 1000 철원 11.2
# 1001 철원 17.5
# 1002 철원 29.8
# 1003 철원 29.6
# 1004 철원 33.0
# 1005 철원 31.8
# 1006 철원 34.3
# 1007 철원 28.6
# 1008 철원 25.4
# 1009 철원 15.4
# 1010 철원 5.9
# 1011 철원 9.6
# 1012 철원 10.5
# 1013 철원 22.4
# 1014 철원 20.4
# 1015 철원 30.5
# 1016 철원 32.7
# 1017 철원 31.0
# 1018 철원 32.5
# 1019 철원 29.9
# 1020 철원 28.1
# 1021 철원 20.0
# 1022 철원 9.1
# 1023 철원 6.7
# 1024 철원 15.8
# 1025 철원 22.2
# 1026 철원 25.3
# 1027 철원 32.2
# 1028 철원 31.1
# 1029 철원 32.6
# 1030 철원 35.3
# 1031 철원 30.1
# 1032 철원 29.0
# 1033 철원 21.2
# 1034 철원 7.1
# 1035 철원 8.1
# 1036 철원 11.9
# 1037 철원 21.2
# 1038 철원 28.9
# 1039 철원 31.3
# 1040 철원 33.0
# 1041 철원 35.6
# 1042 철원 33.3
# 1043 철원 28.8
# 1044 철원 25.7
# 1045 철원 18.1
# 1046 철원 10.0
# 1047 철원 8.2
# 1048 철원 14.6
# 1049 철원 21.4
# 1050 철원 25.6
# 1051 철원 30.8
# 1052 철원 30.9
# 1053 철원 33.5
# 1054 철원 34.3
# 1055 철원 29.7
# 1056 철원 27.3
# 1057 철원 18.6
# 1058 철원 11.8
# 1059 철원 9.9
# 1060 철원 10.6
# 1061 철원 17.4
# 1062 철원 26.6
# 1063 철원 28.9
# 1064 철원 32.0
# 1065 철원 33.6
# 1066 철원 33.8
# 1067 철원 28.9
# 1068 철원 26.8
# 1069 철원 18.2
# 1070 철원 8.5
# 1071 철원 7.7
# 1072 철원 9.8
# 1073 철원 21.9
# 1074 철원 27.1
# 1075 철원 29.5
# 1076 철원 32.3
# 1077 철원 36.0
# 1078 철원 38.4
# 1079 철원 29.4
# 1080 철원 24.6
# 1081 철원 18.6
# 1082 철원 11.4
# 1083 철원 7.6
# 1084 철원 13.2
# 1085 철원 17.1
# 1086 철원 27.6
# 1087 철원 32.5
# 1088 철원 32.1
# 1089 철원 34.5
# 1090 철원 35.1
# 1091 철원 30.3
# 1092 철원 27.8
# 1093 철원 20.8
# 1094 철원 11.3
# 1095 철원 11.0
# 1096 철원 15.8
# 1097 철원 19.9
# 1098 철원 22.8
# 1099 철원 28.8
# 1100 철원 33.6
# 1101 철원 31.7
# 1102 철원 34.9
# 1103 철원 30.1
# 1104 철원 23.1
# 1105 철원 19.8
# 1106 철원 9.9
# 1107 철원 13.1
# 1108 철원 17.3
# 1109 철원 21.7
# 1110 철원 28.0
# 1111 철원 29.7
# 1112 철원 31.1
# 1113 철원 35.7
# 1114 철원 32.1
# 1115 철원 29.6
# 1116 철원 27.6
# 1117 철원 20.1
# 1118 철원 11.1
# 1119 동두천 6.9
# 1120 동두천 15.7
# 1121 동두천 19.4
# 1122 동두천 27.1
# 1123 동두천 31.9
# 1124 동두천 32.1
# 1125 동두천 31.6
# 1126 동두천 30.8
# 1127 동두천 33.2
# 1128 동두천 26.4
# 1129 동두천 20.7
# 1130 동두천 12.2
# 1131 동두천 11.7
# 1132 동두천 9.5
# 1133 동두천 17.6
# 1134 동두천 29.6
# 1135 동두천 28.3
# 1136 동두천 33.4
# 1137 동두천 33.5
# 1138 동두천 35.4
# 1139 동두천 32.2
# 1140 동두천 23.7
# 1141 동두천 18.3
# 1142 동두천 11.4
# 1143 동두천 10.3
# 1144 동두천 8.0
# 1145 동두천 18.6
# 1146 동두천 22.1
# 1147 동두천 30.4
# 1148 동두천 33.7
# 1149 동두천 33.9
# 1150 동두천 34.5
# 1151 동두천 32.1
# 1152 동두천 27.3
# 1153 동두천 20.7
# 1154 동두천 12.4
# 1155 동두천 8.3
# 1156 동두천 11.7
# 1157 동두천 20.8
# 1158 동두천 28.7
# 1159 동두천 33.1
# 1160 동두천 35.1
# 1161 동두천 33.7
# 1162 동두천 35.5
# 1163 동두천 32.4
# 1164 동두천 25.6
# 1165 동두천 17.2
# 1166 동두천 11.1
# 1167 동두천 11.7
# 1168 동두천 14.2
# 1169 동두천 20.1
# 1170 동두천 30.3
# 1171 동두천 28.5
# 1172 동두천 32.6
# 1173 동두천 35.6
# 1174 동두천 31.9
# 1175 동두천 30.8
# 1176 동두천 25.1
# 1177 동두천 17.1
# 1178 동두천 16.0
# 1179 동두천 7.8
# 1180 동두천 11.4
# 1181 동두천 21.7
# 1182 동두천 26.2
# 1183 동두천 31.4
# 1184 동두천 31.7
# 1185 동두천 32.3
# 1186 동두천 33.0
# 1187 동두천 28.8
# 1188 동두천 26.0
# 1189 동두천 20.9
# 1190 동두천 9.5
# 1191 동두천 7.6
# 1192 동두천 19.5
# 1193 동두천 19.9
# 1194 동두천 28.6
# 1195 동두천 26.5
# 1196 동두천 32.4
# 1197 동두천 34.0
# 1198 동두천 35.6
# 1199 동두천 31.2
# 1200 동두천 26.8
# 1201 동두천 22.3
# 1202 동두천 16.3
# 1203 동두천 9.0
# 1204 동두천 11.3
# 1205 동두천 19.0
# 1206 동두천 30.8
# 1207 동두천 30.7
# 1208 동두천 32.9
# 1209 동두천 34.5
# 1210 동두천 34.8
# 1211 동두천 31.9
# 1212 동두천 25.0
# 1213 동두천 23.6
# 1214 동두천 9.4
# 1215 동두천 10.4
# 1216 동두천 12.9
# 1217 동두천 19.4
# 1218 동두천 23.8
# 1219 동두천 29.3
# 1220 동두천 32.4
# 1221 동두천 30.1
# 1222 동두천 34.8
# 1223 동두천 29.4
# 1224 동두천 27.8
# 1225 동두천 21.1
# 1226 동두천 13.7
# 1227 동두천 10.6
# 1228 동두천 16.7
# 1229 동두천 17.6
# 1230 동두천 24.1
# 1231 동두천 30.1
# 1232 동두천 34.3
# 1233 동두천 30.8
# 1234 동두천 31.8
# 1235 동두천 30.3
# 1236 동두천 26.1
# 1237 동두천 21.8
# 1238 동두천 15.1
# 1239 동두천 7.0
# 1240 동두천 11.5
# 1241 동두천 21.6
# 1242 동두천 30.3
# 1243 동두천 30.7
# 1244 동두천 31.1
# 1245 동두천 34.0
# 1246 동두천 35.2
# 1247 동두천 31.8
# 1248 동두천 28.1
# 1249 동두천 20.1
# 1250 동두천 14.0
# 1251 동두천 12.6
# 1252 동두천 16.3
# 1253 동두천 23.8
# 1254 동두천 28.4
# 1255 동두천 32.1
# 1256 동두천 31.9
# 1257 동두천 32.1
# 1258 동두천 34.1
# 1259 동두천 29.3
# 1260 동두천 27.1
# 1261 동두천 22.0
# 1262 동두천 10.5
# 1263 동두천 9.2
# 1264 동두천 19.8
# 1265 동두천 16.5
# 1266 동두천 23.5
# 1267 동두천 29.8
# 1268 동두천 32.7
# 1269 동두천 31.7
# 1270 동두천 33.0
# 1271 동두천 31.0
# 1272 동두천 24.6
# 1273 동두천 18.6
# 1274 동두천 12.9
# 1275 동두천 2.1
# 1276 동두천 14.2
# 1277 동두천 18.4
# 1278 동두천 21.0
# 1279 동두천 32.9
# 1280 동두천 35.2
# 1281 동두천 33.2
# 1282 동두천 33.3
# 1283 동두천 32.1
# 1284 동두천 23.3
# 1285 동두천 26.2
# 1286 동두천 9.2
# 1287 동두천 8.7
# 1288 동두천 12.5
# 1289 동두천 18.0
# 1290 동두천 31.0
# 1291 동두천 30.5
# 1292 동두천 34.1
# 1293 동두천 33.5
# 1294 동두천 36.4
# 1295 동두천 31.6
# 1296 동두천 26.6
# 1297 동두천 18.1
# 1298 동두천 7.9
# 1299 동두천 13.9
# 1300 동두천 13.2
# 1301 동두천 24.7
# 1302 동두천 23.1
# 1303 동두천 32.8
# 1304 동두천 34.3
# 1305 동두천 31.3
# 1306 동두천 33.5
# 1307 동두천 30.3
# 1308 동두천 28.5
# 1309 동두천 21.1
# 1310 동두천 11.2
# 1311 동두천 7.8
# 1312 동두천 17.5
# 1313 동두천 23.9
# 1314 동두천 27.3
# 1315 동두천 33.4
# 1316 동두천 33.3
# 1317 동두천 34.0
# 1318 동두천 36.3
# 1319 동두천 31.1
# 1320 동두천 29.7
# 1321 동두천 22.7
# 1322 동두천 7.0
# 1323 동두천 9.7
# 1324 동두천 14.3
# 1325 동두천 23.2
# 1326 동두천 30.0
# 1327 동두천 33.1
# 1328 동두천 34.5
# 1329 동두천 35.7
# 1330 동두천 34.4
# 1331 동두천 29.9
# 1332 동두천 27.2
# 1333 동두천 21.1
# 1334 동두천 13.9
# 1335 동두천 10.1
# 1336 동두천 16.5
# 1337 동두천 24.0
# 1338 동두천 30.9
# 1339 동두천 32.2
# 1340 동두천 32.6
# 1341 동두천 34.9
# 1342 동두천 35.7
# 1343 동두천 30.9
# 1344 동두천 28.5
# 1345 동두천 20.0
# 1346 동두천 14.6
# 1347 동두천 13.6
# 1348 동두천 12.4
# 1349 동두천 21.0
# 1350 동두천 28.3
# 1351 동두천 30.9
# 1352 동두천 35.5
# 1353 동두천 34.5
# 1354 동두천 35.9
# 1355 동두천 30.4
# 1356 동두천 27.8
# 1357 동두천 19.5
# 1358 동두천 9.7
# 1359 동두천 9.8
# 1360 동두천 11.7
# 1361 동두천 23.8
# 1362 동두천 28.7
# 1363 동두천 30.4
# 1364 동두천 32.2
# 1365 동두천 36.2
# 1366 동두천 38.7
# 1367 동두천 31.5
# 1368 동두천 25.6
# 1369 동두천 20.8
# 1370 동두천 12.6
# 1371 동두천 9.8
# 1372 동두천 14.4
# 1373 동두천 18.5
# 1374 동두천 28.4
# 1375 동두천 32.8
# 1376 동두천 31.8
# 1377 동두천 35.8
# 1378 동두천 35.3
# 1379 동두천 29.9
# 1380 동두천 27.9
# 1381 동두천 19.7
# 1382 동두천 13.3
# 1383 동두천 12.4
# 1384 동두천 17.5
# 1385 동두천 22.3
# 1386 동두천 24.6
# 1387 동두천 29.5
# 1388 동두천 35.5
# 1389 동두천 32.2
# 1390 동두천 35.0
# 1391 동두천 30.1
# 1392 동두천 24.8
# 1393 동두천 19.7
# 1394 동두천 10.9
# 1395 동두천 15.0
# 1396 동두천 19.2
# 1397 동두천 23.9
# 1398 동두천 29.1
# 1399 동두천 29.9
# 1400 동두천 30.8
# 1401 동두천 35.7
# 1402 동두천 32.6
# 1403 동두천 29.6
# 1404 동두천 28.2
# 1405 동두천 22.2
# 1406 동두천 12.8
# 1407 파주 10.7
# 1408 파주 11.8
# 1409 파주 18.4
# 1410 파주 27.2
# 1411 파주 27.8
# 1412 파주 32.0
# 1413 파주 35.0
# 1414 파주 31.8
# 1415 파주 30.4
# 1416 파주 24.8
# 1417 파주 16.9
# 1418 파주 15.9
# 1419 파주 8.3
# 1420 파주 10.5
# 1421 파주 20.9
# 1422 파주 24.6
# 1423 파주 31.6
# 1424 파주 31.5
# 1425 파주 31.6
# 1426 파주 32.4
# 1427 파주 28.7
# 1428 파주 26.2
# 1429 파주 20.0
# 1430 파주 8.7
# 1431 파주 7.0
# 1432 파주 17.4
# 1433 파주 18.4
# 1434 파주 27.4
# 1435 파주 27.4
# 1436 파주 33.6
# 1437 파주 34.4
# 1438 파주 34.6
# 1439 파주 29.7
# 1440 파주 26.7
# 1441 파주 21.9
# 1442 파주 16.2
# 1443 파주 7.6
# 1444 파주 11.4
# 1445 파주 17.5
# 1446 파주 29.3
# 1447 파주 30.7
# 1448 파주 31.7
# 1449 파주 34.0
# 1450 파주 34.4
# 1451 파주 30.8
# 1452 파주 24.4
# 1453 파주 22.5
# 1454 파주 9.5
# 1455 파주 9.5
# 1456 파주 12.9
# 1457 파주 17.7
# 1458 파주 21.8
# 1459 파주 28.3
# 1460 파주 34.3
# 1461 파주 30.5
# 1462 파주 34.9
# 1463 파주 29.9
# 1464 파주 27.2
# 1465 파주 19.8
# 1466 파주 12.8
# 1467 파주 9.5
# 1468 파주 15.5
# 1469 파주 16.4
# 1470 파주 22.7
# 1471 파주 29.3
# 1472 파주 32.1
# 1473 파주 32.2
# 1474 파주 33.0
# 1475 파주 31.0
# 1476 파주 26.4
# 1477 파주 19.0
# 1478 파주 13.5
# 1479 파주 6.7
# 1480 파주 10.3
# 1481 파주 19.1
# 1482 파주 28.6
# 1483 파주 29.6
# 1484 파주 31.1
# 1485 파주 32.7
# 1486 파주 34.9
# 1487 파주 31.0
# 1488 파주 27.0
# 1489 파주 20.5
# 1490 파주 12.6
# 1491 파주 10.7
# 1492 파주 15.0
# 1493 파주 22.1
# 1494 파주 26.3
# 1495 파주 30.9
# 1496 파주 31.3
# 1497 파주 32.3
# 1498 파주 33.3
# 1499 파주 29.1
# 1500 파주 26.5
# 1501 파주 20.5
# 1502 파주 10.5
# 1503 파주 8.3
# 1504 파주 17.4
# 1505 파주 15.5
# 1506 파주 22.1
# 1507 파주 28.0
# 1508 파주 33.2
# 1509 파주 33.3
# 1510 파주 34.1
# 1511 파주 32.5
# 1512 파주 26.0
# 1513 파주 18.0
# 1514 파주 13.4
# 1515 파주 0.7
# 1516 파주 12.8
# 1517 파주 17.0
# 1518 파주 20.3
# 1519 파주 32.0
# 1520 파주 33.7
# 1521 파주 33.1
# 1522 파주 34.1
# 1523 파주 31.3
# 1524 파주 23.1
# 1525 파주 26.1
# 1526 파주 9.9
# 1527 파주 9.1
# 1528 파주 12.8
# 1529 파주 18.2
# 1530 파주 32.0
# 1531 파주 30.1
# 1532 파주 35.3
# 1533 파주 33.5
# 1534 파주 36.5
# 1535 파주 30.8
# 1536 파주 26.5
# 1537 파주 16.3
# 1538 파주 8.3
# 1539 파주 13.3
# 1540 파주 13.1
# 1541 파주 23.1
# 1542 파주 23.7
# 1543 파주 31.6
# 1544 파주 34.0
# 1545 파주 32.0
# 1546 파주 34.9
# 1547 파주 30.9
# 1548 파주 28.5
# 1549 파주 20.0
# 1550 파주 10.0
# 1551 파주 8.1
# 1552 파주 15.9
# 1553 파주 22.6
# 1554 파주 25.5
# 1555 파주 31.3
# 1556 파주 31.1
# 1557 파주 33.4
# 1558 파주 35.8
# 1559 파주 30.2
# 1560 파주 29.0
# 1561 파주 22.6
# 1562 파주 7.3
# 1563 파주 8.8
# 1564 파주 13.0
# 1565 파주 21.3
# 1566 파주 29.1
# 1567 파주 31.6
# 1568 파주 32.8
# 1569 파주 35.0
# 1570 파주 33.8
# 1571 파주 29.9
# 1572 파주 25.9
# 1573 파주 19.6
# 1574 파주 11.1
# 1575 파주 11.3
# 1576 파주 15.5
# 1577 파주 21.6
# 1578 파주 28.1
# 1579 파주 30.6
# 1580 파주 31.0
# 1581 파주 32.9
# 1582 파주 35.0
# 1583 파주 30.5
# 1584 파주 28.4
# 1585 파주 20.2
# 1586 파주 11.4
# 1587 파주 10.1
# 1588 파주 10.7
# 1589 파주 18.8
# 1590 파주 25.1
# 1591 파주 29.1
# 1592 파주 33.1
# 1593 파주 33.5
# 1594 파주 34.9
# 1595 파주 29.5
# 1596 파주 26.8
# 1597 파주 19.9
# 1598 파주 8.0
# 1599 파주 8.0
# 1600 파주 9.6
# 1601 파주 21.1
# 1602 파주 25.3
# 1603 파주 29.9
# 1604 파주 31.0
# 1605 파주 36.7
# 1606 파주 37.6
# 1607 파주 30.1
# 1608 파주 25.5
# 1609 파주 19.4
# 1610 파주 11.4
# 1611 파주 8.0
# 1612 파주 13.2
# 1613 파주 16.8
# 1614 파주 26.6
# 1615 파주 31.3
# 1616 파주 31.6
# 1617 파주 34.7
# 1618 파주 34.7
# 1619 파주 30.0
# 1620 파주 28.0
# 1621 파주 20.5
# 1622 파주 10.9
# 1623 파주 10.9
# 1624 파주 16.4
# 1625 파주 21.6
# 1626 파주 23.0
# 1627 파주 28.5
# 1628 파주 34.4
# 1629 파주 30.7
# 1630 파주 34.2
# 1631 파주 30.5
# 1632 파주 24.2
# 1633 파주 19.8
# 1634 파주 10.6
# 1635 파주 13.4
# 1636 파주 16.8
# 1637 파주 22.0
# 1638 파주 26.7
# 1639 파주 29.4
# 1640 파주 30.2
# 1641 파주 35.1
# 1642 파주 33.0
# 1643 파주 29.5
# 1644 파주 27.3
# 1645 파주 21.8
# 1646 파주 12.3
# 1647 대관령 25.6
# 1648 대관령 29.6
# 1649 대관령 22.9
# 1650 대관령 20.2
# 1651 대관령 18.2
# 1652 대관령 7.3
# 1653 대관령 5.8
# 1654 대관령 3.4
# 1655 대관령 12.2
# 1656 대관령 21.8
# 1657 대관령 27.1
# 1658 대관령 27.3
# 1659 대관령 30.5
# 1660 대관령 27.9
# 1661 대관령 23.4
# 1662 대관령 21.7
# 1663 대관령 15.9
# 1664 대관령 9.0
# 1665 대관령 4.3
# 1666 대관령 9.3
# 1667 대관령 17.5
# 1668 대관령 25.1
# 1669 대관령 24.1
# 1670 대관령 26.5
# 1671 대관령 30.1
# 1672 대관령 32.7
# 1673 대관령 23.3
# 1674 대관령 20.7
# 1675 대관령 12.7
# 1676 대관령 4.7
# 1677 대관령 5.2
# 1678 대관령 5.9
# 1679 대관령 13.9
# 1680 대관령 21.4
# 1681 대관령 28.2
# 1682 대관령 28.0
# 1683 대관령 27.2
# 1684 대관령 29.1
# 1685 대관령 23.7
# 1686 대관령 20.1
# 1687 대관령 17.7
# 1688 대관령 8.2
# 1689 대관령 2.9
# 1690 대관령 4.3
# 1691 대관령 9.7
# 1692 대관령 21.7
# 1693 대관령 23.5
# 1694 대관령 26.4
# 1695 대관령 29.1
# 1696 대관령 29.8
# 1697 대관령 27.8
# 1698 대관령 20.6
# 1699 대관령 13.9
# 1700 대관령 10.4
# 1701 대관령 7.6
# 1702 대관령 8.5
# 1703 대관령 9.7
# 1704 대관령 19.7
# 1705 대관령 26.2
# 1706 대관령 26.0
# 1707 대관령 27.4
# 1708 대관령 27.9
# 1709 대관령 24.5
# 1710 대관령 21.2
# 1711 대관령 15.5
# 1712 대관령 9.4
# 1713 대관령 1.2
# 1714 대관령 13.8
# 1715 대관령 14.6
# 1716 대관령 22.2
# 1717 대관령 25.3
# 1718 대관령 26.1
# 1719 대관령 32.0
# 1720 대관령 29.9
# 1721 대관령 25.9
# 1722 대관령 23.6
# 1723 대관령 15.8
# 1724 대관령 11.9
# 1725 대관령 3.2
# 1726 대관령 6.3
# 1727 대관령 14.4
# 1728 대관령 22.2
# 1729 대관령 26.5
# 1730 대관령 27.8
# 1731 대관령 31.0
# 1732 대관령 30.1
# 1733 대관령 23.5
# 1734 대관령 24.0
# 1735 대관령 14.1
# 1736 대관령 11.3
# 1737 대관령 7.2
# 1738 대관령 13.2
# 1739 대관령 14.3
# 1740 대관령 21.7
# 1741 대관령 29.2
# 1742 대관령 26.9
# 1743 대관령 28.6
# 1744 대관령 27.8
# 1745 대관령 24.0
# 1746 대관령 22.6
# 1747 대관령 20.6
# 1748 대관령 11.2
# 1749 대관령 6.0
# 1750 대관령 5.8
# 1751 대관령 15.0
# 1752 대관령 18.4
# 1753 대관령 28.0
# 1754 대관령 29.4
# 1755 대관령 26.9
# 1756 대관령 25.4
# 1757 대관령 23.3
# 1758 대관령 21.1
# 1759 대관령 16.1
# 1760 대관령 9.1
# 1761 대관령 1.1
# 1762 대관령 8.8
# 1763 대관령 15.5
# 1764 대관령 19.9
# 1765 대관령 25.8
# 1766 대관령 27.2
# 1767 대관령 30.1
# 1768 대관령 26.6
# 1769 대관령 25.6
# 1770 대관령 19.2
# 1771 대관령 9.3
# 1772 대관령 7.0
# 1773 대관령 6.2
# 1774 대관령 7.4
# 1775 대관령 15.5
# 1776 대관령 23.8
# 1777 대관령 26.4
# 1778 대관령 26.1
# 1779 대관령 28.9
# 1780 대관령 29.2
# 1781 대관령 22.4
# 1782 대관령 24.7
# 1783 대관령 16.9
# 1784 대관령 4.5
# 1785 대관령 4.8
# 1786 대관령 5.3
# 1787 대관령 14.6
# 1788 대관령 25.6
# 1789 대관령 31.0
# 1790 대관령 28.0
# 1791 대관령 26.6
# 1792 대관령 31.1
# 1793 대관령 25.4
# 1794 대관령 21.2
# 1795 대관령 14.2
# 1796 대관령 6.0
# 1797 대관령 -0.1
# 1798 대관령 4.0
# 1799 대관령 10.2
# 1800 대관령 20.0
# 1801 대관령 25.7
# 1802 대관령 27.8
# 1803 대관령 29.4
# 1804 대관령 31.0
# 1805 대관령 22.2
# 1806 대관령 20.7
# 1807 대관령 18.2
# 1808 대관령 8.6
# 1809 대관령 1.7
# 1810 대관령 7.7
# 1811 대관령 10.5
# 1812 대관령 22.3
# 1813 대관령 25.3
# 1814 대관령 26.2
# 1815 대관령 28.9
# 1816 대관령 28.9
# 1817 대관령 26.8
# 1818 대관령 20.9
# 1819 대관령 12.4
# 1820 대관령 5.3
# 1821 대관령 3.7
# 1822 대관령 1.4
# 1823 대관령 12.5
# 1824 대관령 20.6
# 1825 대관령 24.8
# 1826 대관령 25.8
# 1827 대관령 29.3
# 1828 대관령 27.5
# 1829 대관령 22.9
# 1830 대관령 18.2
# 1831 대관령 12.0
# 1832 대관령 9.0
# 1833 대관령 4.6
# 1834 대관령 7.8
# 1835 대관령 12.6
# 1836 대관령 21.1
# 1837 대관령 26.2
# 1838 대관령 28.3
# 1839 대관령 26.2
# 1840 대관령 25.4
# 1841 대관령 23.8
# 1842 대관령 23.6
# 1843 대관령 16.2
# 1844 대관령 9.7
# 1845 대관령 3.8
# 1846 대관령 4.2
# 1847 대관령 11.0
# 1848 대관령 21.3
# 1849 대관령 27.3
# 1850 대관령 25.2
# 1851 대관령 25.2
# 1852 대관령 28.6
# 1853 대관령 22.9
# 1854 대관령 20.5
# 1855 대관령 13.4
# 1856 대관령 9.9
# 1857 대관령 8.5
# 1858 대관령 5.5
# 1859 대관령 9.3
# 1860 대관령 22.0
# 1861 대관령 24.7
# 1862 대관령 24.6
# 1863 대관령 28.0
# 1864 대관령 27.7
# 1865 대관령 22.8
# 1866 대관령 18.0
# 1867 대관령 14.8
# 1868 대관령 10.8
# 1869 대관령 4.3
# 1870 대관령 7.7
# 1871 대관령 13.9
# 1872 대관령 18.8
# 1873 대관령 23.9
# 1874 대관령 25.6
# 1875 대관령 28.9
# 1876 대관령 29.2
# 1877 대관령 26.5
# 1878 대관령 20.5
# 1879 대관령 15.7
# 1880 대관령 9.7
# 1881 대관령 7.6
# 1882 대관령 5.8
# 1883 대관령 12.9
# 1884 대관령 20.2
# 1885 대관령 24.1
# 1886 대관령 26.5
# 1887 대관령 26.2
# 1888 대관령 24.4
# 1889 대관령 23.4
# 1890 대관령 21.5
# 1891 대관령 15.1
# 1892 대관령 11.4
# 1893 대관령 4.5
# 1894 대관령 12.0
# 1895 대관령 14.9
# 1896 대관령 22.3
# 1897 대관령 21.4
# 1898 대관령 26.5
# 1899 대관령 28.4
# 1900 대관령 25.5
# 1901 대관령 25.6
# 1902 대관령 22.5
# 1903 대관령 14.8
# 1904 대관령 10.3
# 1905 대관령 1.7
# 1906 대관령 12.6
# 1907 대관령 12.0
# 1908 대관령 22.0
# 1909 대관령 24.2
# 1910 대관령 25.3
# 1911 대관령 24.7
# 1912 대관령 24.6
# 1913 대관령 24.1
# 1914 대관령 19.6
# 1915 대관령 19.0
# 1916 대관령 4.8
# 1917 대관령 5.0
# 1918 대관령 10.4
# 1919 대관령 10.6
# 1920 대관령 21.0
# 1921 대관령 24.0
# 1922 대관령 26.8
# 1923 대관령 30.6
# 1924 대관령 31.0
# 1925 대관령 27.8
# 1926 대관령 21.0
# 1927 대관령 16.6
# 1928 대관령 13.1
# 1929 대관령 5.3
# 1930 대관령 6.0
# 1931 대관령 11.9
# 1932 대관령 22.0
# 1933 대관령 24.2
# 1934 대관령 25.0
# 1935 대관령 28.4
# 1936 대관령 29.3
# 1937 대관령 24.0
# 1938 대관령 23.6
# 1939 대관령 14.2
# 1940 대관령 4.0
# 1941 대관령 5.6
# 1942 대관령 11.4
# 1943 대관령 10.2
# 1944 대관령 24.0
# 1945 대관령 24.3
# 1946 대관령 27.1
# 1947 대관령 29.5
# 1948 대관령 29.5
# 1949 대관령 24.7
# 1950 대관령 20.9
# 1951 대관령 15.3
# 1952 대관령 10.1
# 1953 대관령 5.5
# 1954 대관령 10.0
# 1955 대관령 16.5
# 1956 대관령 19.3
# 1957 대관령 23.8
# 1958 대관령 27.8
# 1959 대관령 29.0
# 1960 대관령 27.9
# 1961 대관령 27.6
# 1962 대관령 20.7
# 1963 대관령 16.4
# 1964 대관령 6.9
# 1965 대관령 3.7
# 1966 대관령 8.7
# 1967 대관령 18.0
# 1968 대관령 24.6
# 1969 대관령 23.9
# 1970 대관령 26.3
# 1971 대관령 27.3
# 1972 대관령 26.1
# 1973 대관령 26.8
# 1974 대관령 19.8
# 1975 대관령 17.3
# 1976 대관령 8.3
# 1977 대관령 5.4
# 1978 대관령 5.8
# 1979 대관령 14.6
# 1980 대관령 22.8
# 1981 대관령 24.6
# 1982 대관령 30.1
# 1983 대관령 27.1
# 1984 대관령 26.6
# 1985 대관령 26.9
# 1986 대관령 19.8
# 1987 대관령 17.2
# 1988 대관령 7.2
# 1989 대관령 3.9
# 1990 대관령 4.2
# 1991 대관령 14.6
# 1992 대관령 20.2
# 1993 대관령 30.0
# 1994 대관령 29.6
# 1995 대관령 30.3
# 1996 대관령 28.9
# 1997 대관령 27.4
# 1998 대관령 23.5
# 1999 대관령 18.8
# 2000 대관령 9.4
# 2001 대관령 3.2
# 2002 대관령 9.9
# 2003 대관령 17.5
# 2004 대관령 23.0
# 2005 대관령 28.0
# 2006 대관령 29.7
# 2007 대관령 31.3
# 2008 대관령 31.1
# 2009 대관령 26.3
# 2010 대관령 23.4
# 2011 대관령 14.8
# 2012 대관령 5.9
# 2013 대관령 8.7
# 2014 대관령 9.0
# 2015 대관령 17.1
# 2016 대관령 25.2
# 2017 대관령 27.2
# 2018 대관령 29.7
# 2019 대관령 30.6
# 2020 대관령 28.9
# 2021 대관령 28.4
# 2022 대관령 22.9
# 2023 대관령 13.3
# 2024 대관령 13.5
# 2025 대관령 2.5
# 2026 대관령 6.4
# 2027 대관령 14.1
# 2028 대관령 23.6
# 2029 대관령 25.0
# 2030 대관령 25.8
# 2031 대관령 26.1
# 2032 대관령 29.2
# 2033 대관령 25.2
# 2034 대관령 21.2
# 2035 대관령 21.5
# 2036 대관령 10.1
# 2037 대관령 8.0
# 2038 대관령 16.5
# 2039 대관령 18.2
# 2040 대관령 27.7
# 2041 대관령 24.7
# 2042 대관령 27.5
# 2043 대관령 31.3
# 2044 대관령 30.0
# 2045 대관령 26.1
# 2046 대관령 21.6
# 2047 대관령 17.2
# 2048 대관령 11.5
# 2049 대관령 4.0
# 2050 대관령 4.4
# 2051 대관령 15.9
# 2052 대관령 30.1
# 2053 대관령 24.8
# 2054 대관령 32.3
# 2055 대관령 31.9
# 2056 대관령 29.2
# 2057 대관령 27.0
# 2058 대관령 20.2
# 2059 대관령 19.6
# 2060 대관령 3.2
# 2061 대관령 5.6
# 2062 대관령 10.6
# 2063 대관령 14.5
# 2064 대관령 18.9
# 2065 대관령 23.9
# 2066 대관령 27.5
# 2067 대관령 28.2
# 2068 대관령 30.6
# 2069 대관령 25.0
# 2070 대관령 23.3
# 2071 대관령 16.2
# 2072 대관령 8.0
# 2073 대관령 5.9
# 2074 대관령 9.8
# 2075 대관령 15.4
# 2076 대관령 20.7
# 2077 대관령 24.3
# 2078 대관령 29.6
# 2079 대관령 27.9
# 2080 대관령 30.2
# 2081 대관령 27.5
# 2082 대관령 21.5
# 2083 대관령 16.0
# 2084 대관령 7.9
# 2085 대관령 5.5
# 2086 대관령 5.4
# 2087 대관령 15.3
# 2088 대관령 21.5
# 2089 대관령 26.7
# 2090 대관령 27.1
# 2091 대관령 29.7
# 2092 대관령 30.1
# 2093 대관령 26.7
# 2094 대관령 23.7
# 2095 대관령 15.9
# 2096 대관령 9.1
# 2097 대관령 4.7
# 2098 대관령 14.3
# 2099 대관령 17.9
# 2100 대관령 23.9
# 2101 대관령 27.5
# 2102 대관령 29.6
# 2103 대관령 27.5
# 2104 대관령 29.9
# 2105 대관령 26.8
# 2106 대관령 22.8
# 2107 대관령 15.4
# 2108 대관령 8.9
# 2109 대관령 8.0
# 2110 대관령 14.2
# 2111 대관령 13.8
# 2112 대관령 18.5
# 2113 대관령 27.3
# 2114 대관령 26.9
# 2115 대관령 29.2
# 2116 대관령 30.1
# 2117 대관령 29.0
# 2118 대관령 22.0
# 2119 대관령 13.5
# 2120 대관령 11.2
# 2121 대관령 0.2
# 2122 대관령 12.4
# 2123 대관령 14.8
# 2124 대관령 19.2
# 2125 대관령 24.2
# 2126 대관령 27.0
# 2127 대관령 26.8
# 2128 대관령 28.3
# 2129 대관령 27.9
# 2130 대관령 19.9
# 2131 대관령 19.7
# 2132 대관령 6.8
# 2133 대관령 3.8
# 2134 대관령 8.7
# 2135 대관령 10.7
# 2136 대관령 25.3
# 2137 대관령 25.4
# 2138 대관령 25.2
# 2139 대관령 29.7
# 2140 대관령 30.7
# 2141 대관령 25.7
# 2142 대관령 20.6
# 2143 대관령 11.7
# 2144 대관령 6.3
# 2145 대관령 7.5
# 2146 대관령 9.4
# 2147 대관령 18.0
# 2148 대관령 22.7
# 2149 대관령 29.8
# 2150 대관령 27.9
# 2151 대관령 29.1
# 2152 대관령 30.1
# 2153 대관령 25.5
# 2154 대관령 22.6
# 2155 대관령 15.4
# 2156 대관령 6.5
# 2157 대관령 6.1
# 2158 대관령 10.7
# 2159 대관령 19.7
# 2160 대관령 22.5
# 2161 대관령 30.0
# 2162 대관령 30.6
# 2163 대관령 30.2
# 2164 대관령 30.3
# 2165 대관령 27.1
# 2166 대관령 21.6
# 2167 대관령 14.7
# 2168 대관령 6.2
# 2169 대관령 7.0
# 2170 대관령 7.2
# 2171 대관령 18.8
# 2172 대관령 23.3
# 2173 대관령 29.1
# 2174 대관령 28.1
# 2175 대관령 29.0
# 2176 대관령 30.0
# 2177 대관령 23.8
# 2178 대관령 22.4
# 2179 대관령 17.5
# 2180 대관령 9.4
# 2181 대관령 6.8
# 2182 대관령 13.7
# 2183 대관령 17.9
# 2184 대관령 23.3
# 2185 대관령 27.4
# 2186 대관령 27.8
# 2187 대관령 30.2
# 2188 대관령 32.4
# 2189 대관령 25.8
# 2190 대관령 22.8
# 2191 대관령 15.1
# 2192 대관령 11.6
# 2193 대관령 6.9
# 2194 대관령 7.3
# 2195 대관령 12.2
# 2196 대관령 23.0
# 2197 대관령 26.8
# 2198 대관령 29.0
# 2199 대관령 31.1
# 2200 대관령 29.3
# 2201 대관령 25.9
# 2202 대관령 21.6
# 2203 대관령 14.8
# 2204 대관령 4.5
# 2205 대관령 3.9
# 2206 대관령 5.3
# 2207 대관령 17.5
# 2208 대관령 27.3
# 2209 대관령 28.3
# 2210 대관령 28.5
# 2211 대관령 32.9
# 2212 대관령 32.2
# 2213 대관령 23.2
# 2214 대관령 18.6
# 2215 대관령 16.8
# 2216 대관령 11.1
# 2217 대관령 5.3
# 2218 대관령 8.1
# 2219 대관령 15.0
# 2220 대관령 24.4
# 2221 대관령 29.6
# 2222 대관령 28.2
# 2223 대관령 29.4
# 2224 대관령 30.2
# 2225 대관령 26.7
# 2226 대관령 22.7
# 2227 대관령 15.6
# 2228 대관령 9.8
# 2229 대관령 9.3
# 2230 대관령 10.3
# 2231 대관령 20.5
# 2232 대관령 20.1
# 2233 대관령 25.2
# 2234 대관령 31.6
# 2235 대관령 28.7
# 2236 대관령 30.8
# 2237 대관령 26.3
# 2238 대관령 19.7
# 2239 대관령 18.3
# 2240 대관령 8.0
# 2241 대관령 7.6
# 2242 대관령 15.6
# 2243 대관령 16.1
# 2244 대관령 20.9
# 2245 대관령 25.2
# 2246 대관령 27.8
# 2247 대관령 30.1
# 2248 대관령 30.6
# 2249 대관령 25.5
# 2250 대관령 26.1
# 2251 대관령 15.1
# 2252 대관령 9.0
# 2253 춘천 7.8
# 2254 춘천 10.6
# 2255 춘천 12.6
# 2256 춘천 26.9
# 2257 춘천 30.9
# 2258 춘천 31.8
# 2259 춘천 31.7
# 2260 춘천 34.0
# 2261 춘천 27.0
# 2262 춘천 25.4
# 2263 춘천 18.0
# 2264 춘천 9.0
# 2265 춘천 8.4
# 2266 춘천 10.7
# 2267 춘천 17.2
# 2268 춘천 26.2
# 2269 춘천 30.7
# 2270 춘천 31.1
# 2271 춘천 34.4
# 2272 춘천 34.1
# 2273 춘천 30.7
# 2274 춘천 22.7
# 2275 춘천 19.4
# 2276 춘천 7.2
# 2277 춘천 9.4
# 2278 춘천 11.6
# 2279 춘천 17.2
# 2280 춘천 25.3
# 2281 춘천 28.7
# 2282 춘천 33.1
# 2283 춘천 34.6
# 2284 춘천 32.9
# 2285 춘천 30.6
# 2286 춘천 27.7
# 2287 춘천 17.5
# 2288 춘천 15.3
# 2289 춘천 11.4
# 2290 춘천 7.8
# 2291 춘천 19.0
# 2292 춘천 25.0
# 2293 춘천 27.0
# 2294 춘천 32.1
# 2295 춘천 31.3
# 2296 춘천 32.4
# 2297 춘천 30.6
# 2298 춘천 24.2
# 2299 춘천 16.9
# 2300 춘천 11.8
# 2301 춘천 6.3
# 2302 춘천 13.2
# 2303 춘천 17.8
# 2304 춘천 28.0
# 2305 춘천 30.9
# 2306 춘천 31.6
# 2307 춘천 33.4
# 2308 춘천 35.0
# 2309 춘천 31.1
# 2310 춘천 24.7
# 2311 춘천 17.2
# 2312 춘천 12.8
# 2313 춘천 7.9
# 2314 춘천 12.2
# 2315 춘천 20.5
# 2316 춘천 25.5
# 2317 춘천 31.0
# 2318 춘천 32.1
# 2319 춘천 33.1
# 2320 춘천 34.4
# 2321 춘천 28.9
# 2322 춘천 23.2
# 2323 춘천 18.7
# 2324 춘천 9.6
# 2325 춘천 11.2
# 2326 춘천 8.3
# 2327 춘천 18.9
# 2328 춘천 25.6
# 2329 춘천 28.8
# 2330 춘천 33.8
# 2331 춘천 36.6
# 2332 춘천 32.1
# 2333 춘천 26.8
# 2334 춘천 24.6
# 2335 춘천 18.4
# 2336 춘천 9.5
# 2337 춘천 9.2
# 2338 춘천 12.1
# 2339 춘천 21.5
# 2340 춘천 28.5
# 2341 춘천 28.1
# 2342 춘천 31.9
# 2343 춘천 35.3
# 2344 춘천 35.4
# 2345 춘천 28.4
# 2346 춘천 24.4
# 2347 춘천 15.4
# 2348 춘천 7.4
# 2349 춘천 7.0
# 2350 춘천 12.5
# 2351 춘천 20.2
# 2352 춘천 24.2
# 2353 춘천 31.3
# 2354 춘천 31.5
# 2355 춘천 31.8
# 2356 춘천 34.6
# 2357 춘천 29.3
# 2358 춘천 23.0
# 2359 춘천 20.2
# 2360 춘천 8.4
# 2361 춘천 8.0
# 2362 춘천 10.2
# 2363 춘천 15.4
# 2364 춘천 29.2
# 2365 춘천 27.8
# 2366 춘천 33.8
# 2367 춘천 33.6
# 2368 춘천 34.0
# 2369 춘천 29.4
# 2370 춘천 24.7
# 2371 춘천 18.8
# 2372 춘천 13.4
# 2373 춘천 9.4
# 2374 춘천 11.2
# 2375 춘천 15.6
# 2376 춘천 26.2
# 2377 춘천 32.2
# 2378 춘천 32.7
# 2379 춘천 34.0
# 2380 춘천 32.3
# 2381 춘천 28.6
# 2382 춘천 23.8
# 2383 춘천 17.8
# 2384 춘천 12.0
# 2385 춘천 3.6
# 2386 춘천 17.0
# 2387 춘천 21.2
# 2388 춘천 28.2
# 2389 춘천 29.3
# 2390 춘천 34.2
# 2391 춘천 35.5
# 2392 춘천 33.2
# 2393 춘천 30.6
# 2394 춘천 27.7
# 2395 춘천 19.8
# 2396 춘천 12.4
# 2397 춘천 7.6
# 2398 춘천 9.7
# 2399 춘천 20.5
# 2400 춘천 25.3
# 2401 춘천 32.1
# 2402 춘천 32.9
# 2403 춘천 36.5
# 2404 춘천 34.1
# 2405 춘천 30.2
# 2406 춘천 26.4
# 2407 춘천 19.4
# 2408 춘천 13.2
# 2409 춘천 12.7
# 2410 춘천 17.8
# 2411 춘천 19.8
# 2412 춘천 23.8
# 2413 춘천 31.5
# 2414 춘천 30.5
# 2415 춘천 32.3
# 2416 춘천 34.5
# 2417 춘천 28.7
# 2418 춘천 26.0
# 2419 춘천 22.8
# 2420 춘천 10.7
# 2421 춘천 8.3
# 2422 춘천 12.4
# 2423 춘천 20.4
# 2424 춘천 22.2
# 2425 춘천 32.7
# 2426 춘천 33.2
# 2427 춘천 32.6
# 2428 춘천 30.7
# 2429 춘천 29.1
# 2430 춘천 25.2
# 2431 춘천 19.0
# 2432 춘천 11.1
# 2433 춘천 2.3
# 2434 춘천 11.7
# 2435 춘천 21.9
# 2436 춘천 26.2
# 2437 춘천 30.0
# 2438 춘천 32.0
# 2439 춘천 35.3
# 2440 춘천 33.4
# 2441 춘천 28.6
# 2442 춘천 24.8
# 2443 춘천 14.5
# 2444 춘천 10.7
# 2445 춘천 7.0
# 2446 춘천 12.7
# 2447 춘천 19.2
# 2448 춘천 28.8
# 2449 춘천 29.4
# 2450 춘천 30.9
# 2451 춘천 34.2
# 2452 춘천 35.5
# 2453 춘천 30.6
# 2454 춘천 27.2
# 2455 춘천 21.2
# 2456 춘천 9.3
# 2457 춘천 8.6
# 2458 춘천 11.6
# 2459 춘천 20.6
# 2460 춘천 27.2
# 2461 춘천 31.0
# 2462 춘천 33.0
# 2463 춘천 31.0
# 2464 춘천 35.5
# 2465 춘천 31.4
# 2466 춘천 24.4
# 2467 춘천 18.4
# 2468 춘천 10.9
# 2469 춘천 4.2
# 2470 춘천 10.8
# 2471 춘천 15.3
# 2472 춘천 24.6
# 2473 춘천 30.0
# 2474 춘천 34.7
# 2475 춘천 34.5
# 2476 춘천 35.0
# 2477 춘천 28.2
# 2478 춘천 25.4
# 2479 춘천 20.8
# 2480 춘천 12.4
# 2481 춘천 3.5
# 2482 춘천 9.7
# 2483 춘천 19.3
# 2484 춘천 26.6
# 2485 춘천 30.7
# 2486 춘천 33.5
# 2487 춘천 36.0
# 2488 춘천 34.8
# 2489 춘천 30.9
# 2490 춘천 25.9
# 2491 춘천 18.6
# 2492 춘천 8.0
# 2493 춘천 7.0
# 2494 춘천 7.0
# 2495 춘천 19.2
# 2496 춘천 27.3
# 2497 춘천 32.2
# 2498 춘천 33.2
# 2499 춘천 33.3
# 2500 춘천 34.3
# 2501 춘천 31.6
# 2502 춘천 24.1
# 2503 춘천 15.3
# 2504 춘천 11.3
# 2505 춘천 6.1
# 2506 춘천 11.0
# 2507 춘천 17.5
# 2508 춘천 26.0
# 2509 춘천 31.1
# 2510 춘천 33.5
# 2511 춘천 33.3
# 2512 춘천 32.5
# 2513 춘천 29.4
# 2514 춘천 26.8
# 2515 춘천 17.8
# 2516 춘천 10.8
# 2517 춘천 8.9
# 2518 춘천 11.3
# 2519 춘천 17.0
# 2520 춘천 27.4
# 2521 춘천 30.4
# 2522 춘천 31.8
# 2523 춘천 34.0
# 2524 춘천 36.3
# 2525 춘천 30.9
# 2526 춘천 24.7
# 2527 춘천 18.2
# 2528 춘천 14.0
# 2529 춘천 8.2
# 2530 춘천 12.8
# 2531 춘천 16.5
# 2532 춘천 29.9
# 2533 춘천 29.3
# 2534 춘천 32.3
# 2535 춘천 33.1
# 2536 춘천 35.1
# 2537 춘천 29.3
# 2538 춘천 22.7
# 2539 춘천 18.4
# 2540 춘천 14.0
# 2541 춘천 5.3
# 2542 춘천 12.4
# 2543 춘천 20.2
# 2544 춘천 29.3
# 2545 춘천 27.6
# 2546 춘천 30.9
# 2547 춘천 34.9
# 2548 춘천 35.6
# 2549 춘천 31.3
# 2550 춘천 25.0
# 2551 춘천 20.4
# 2552 춘천 11.9
# 2553 춘천 6.9
# 2554 춘천 9.6
# 2555 춘천 20.6
# 2556 춘천 25.2
# 2557 춘천 31.5
# 2558 춘천 31.6
# 2559 춘천 32.0
# 2560 춘천 34.1
# 2561 춘천 31.0
# 2562 춘천 24.9
# 2563 춘천 17.4
# 2564 춘천 11.2
# 2565 춘천 7.1
# 2566 춘천 13.6
# 2567 춘천 20.3
# 2568 춘천 26.3
# 2569 춘천 31.0
# 2570 춘천 31.6
# 2571 춘천 33.4
# 2572 춘천 32.7
# 2573 춘천 30.6
# 2574 춘천 24.5
# 2575 춘천 16.3
# 2576 춘천 10.5
# 2577 춘천 6.9
# 2578 춘천 15.2
# 2579 춘천 18.5
# 2580 춘천 27.5
# 2581 춘천 32.3
# 2582 춘천 31.2
# 2583 춘천 32.9
# 2584 춘천 31.4
# 2585 춘천 29.7
# 2586 춘천 24.8
# 2587 춘천 18.8
# 2588 춘천 8.5
# 2589 춘천 9.4
# 2590 춘천 12.2
# 2591 춘천 20.2
# 2592 춘천 29.3
# 2593 춘천 28.6
# 2594 춘천 34.9
# 2595 춘천 36.5
# 2596 춘천 35.3
# 2597 춘천 30.8
# 2598 춘천 23.8
# 2599 춘천 20.8
# 2600 춘천 12.6
# 2601 춘천 9.9
# 2602 춘천 11.2
# 2603 춘천 17.4
# 2604 춘천 27.3
# 2605 춘천 28.8
# 2606 춘천 31.9
# 2607 춘천 33.8
# 2608 춘천 34.1
# 2609 춘천 29.0
# 2610 춘천 24.8
# 2611 춘천 18.8
# 2612 춘천 7.5
# 2613 춘천 9.4
# 2614 춘천 14.7
# 2615 춘천 17.6
# 2616 춘천 27.7
# 2617 춘천 31.9
# 2618 춘천 32.8
# 2619 춘천 34.0
# 2620 춘천 35.2
# 2621 춘천 29.8
# 2622 춘천 23.8
# 2623 춘천 17.4
# 2624 춘천 9.7
# 2625 춘천 5.8
# 2626 춘천 15.3
# 2627 춘천 20.9
# 2628 춘천 23.5
# 2629 춘천 28.8
# 2630 춘천 34.4
# 2631 춘천 35.4
# 2632 춘천 34.9
# 2633 춘천 32.0
# 2634 춘천 24.9
# 2635 춘천 18.9
# 2636 춘천 11.5
# 2637 춘천 7.6
# 2638 춘천 15.9
# 2639 춘천 21.6
# 2640 춘천 28.2
# 2641 춘천 31.5
# 2642 춘천 32.2
# 2643 춘천 32.6
# 2644 춘천 31.8
# 2645 춘천 33.0
# 2646 춘천 25.9
# 2647 춘천 20.7
# 2648 춘천 13.2
# 2649 춘천 12.0
# 2650 춘천 11.3
# 2651 춘천 18.3
# 2652 춘천 30.2
# 2653 춘천 29.2
# 2654 춘천 33.2
# 2655 춘천 35.0
# 2656 춘천 36.2
# 2657 춘천 32.4
# 2658 춘천 23.1
# 2659 춘천 17.3
# 2660 춘천 11.1
# 2661 춘천 7.9
# 2662 춘천 7.6
# 2663 춘천 19.7
# 2664 춘천 24.0
# 2665 춘천 32.0
# 2666 춘천 35.0
# 2667 춘천 35.2
# 2668 춘천 36.0
# 2669 춘천 31.4
# 2670 춘천 26.0
# 2671 춘천 20.1
# 2672 춘천 11.5
# 2673 춘천 7.3
# 2674 춘천 13.5
# 2675 춘천 22.1
# 2676 춘천 28.0
# 2677 춘천 32.9
# 2678 춘천 36.0
# 2679 춘천 34.5
# 2680 춘천 35.8
# 2681 춘천 31.8
# 2682 춘천 25.1
# 2683 춘천 18.1
# 2684 춘천 10.7
# 2685 춘천 9.1
# 2686 춘천 15.5
# 2687 춘천 20.7
# 2688 춘천 30.4
# 2689 춘천 28.9
# 2690 춘천 33.2
# 2691 춘천 35.7
# 2692 춘천 32.2
# 2693 춘천 32.2
# 2694 춘천 24.5
# 2695 춘천 18.6
# 2696 춘천 16.6
# 2697 춘천 6.8
# 2698 춘천 12.8
# 2699 춘천 20.3
# 2700 춘천 26.0
# 2701 춘천 31.4
# 2702 춘천 31.6
# 2703 춘천 33.3
# 2704 춘천 33.1
# 2705 춘천 29.9
# 2706 춘천 25.3
# 2707 춘천 22.2
# 2708 춘천 8.8
# 2709 춘천 7.7
# 2710 춘천 19.2
# 2711 춘천 21.3
# 2712 춘천 29.2
# 2713 춘천 27.4
# 2714 춘천 33.9
# 2715 춘천 36.0
# 2716 춘천 35.2
# 2717 춘천 30.2
# 2718 춘천 27.1
# 2719 춘천 20.5
# 2720 춘천 13.7
# 2721 춘천 9.7
# 2722 춘천 9.9
# 2723 춘천 19.6
# 2724 춘천 32.0
# 2725 춘천 31.0
# 2726 춘천 34.0
# 2727 춘천 35.0
# 2728 춘천 35.6
# 2729 춘천 31.2
# 2730 춘천 25.6
# 2731 춘천 20.6
# 2732 춘천 5.9
# 2733 춘천 10.1
# 2734 춘천 12.7
# 2735 춘천 17.6
# 2736 춘천 22.2
# 2737 춘천 29.0
# 2738 춘천 31.5
# 2739 춘천 31.0
# 2740 춘천 35.5
# 2741 춘천 30.0
# 2742 춘천 27.4
# 2743 춘천 19.5
# 2744 춘천 8.7
# 2745 춘천 9.7
# 2746 춘천 15.1
# 2747 춘천 16.7
# 2748 춘천 24.5
# 2749 춘천 29.2
# 2750 춘천 34.8
# 2751 춘천 32.2
# 2752 춘천 33.4
# 2753 춘천 30.7
# 2754 춘천 25.7
# 2755 춘천 18.6
# 2756 춘천 11.3
# 2757 춘천 6.0
# 2758 춘천 10.8
# 2759 춘천 20.4
# 2760 춘천 29.2
# 2761 춘천 30.2
# 2762 춘천 30.7
# 2763 춘천 34.2
# 2764 춘천 35.1
# 2765 춘천 30.8
# 2766 춘천 25.1
# 2767 춘천 19.1
# 2768 춘천 12.7
# 2769 춘천 9.4
# 2770 춘천 14.9
# 2771 춘천 23.0
# 2772 춘천 28.0
# 2773 춘천 31.1
# 2774 춘천 32.8
# 2775 춘천 32.3
# 2776 춘천 34.1
# 2777 춘천 30.0
# 2778 춘천 27.0
# 2779 춘천 18.7
# 2780 춘천 10.8
# 2781 춘천 5.3
# 2782 춘천 17.8
# 2783 춘천 15.0
# 2784 춘천 23.9
# 2785 춘천 31.1
# 2786 춘천 33.2
# 2787 춘천 33.1
# 2788 춘천 33.9
# 2789 춘천 31.8
# 2790 춘천 24.5
# 2791 춘천 17.7
# 2792 춘천 9.3
# 2793 춘천 1.1
# 2794 춘천 14.9
# 2795 춘천 19.1
# 2796 춘천 21.5
# 2797 춘천 29.6
# 2798 춘천 34.2
# 2799 춘천 33.1
# 2800 춘천 33.7
# 2801 춘천 31.7
# 2802 춘천 21.9
# 2803 춘천 24.8
# 2804 춘천 7.8
# 2805 춘천 8.1
# 2806 춘천 12.2
# 2807 춘천 17.9
# 2808 춘천 30.1
# 2809 춘천 31.2
# 2810 춘천 33.1
# 2811 춘천 32.8
# 2812 춘천 36.8
# 2813 춘천 30.5
# 2814 춘천 25.0
# 2815 춘천 15.2
# 2816 춘천 7.4
# 2817 춘천 5.3
# 2818 춘천 11.2
# 2819 춘천 21.9
# 2820 춘천 22.5
# 2821 춘천 31.4
# 2822 춘천 33.4
# 2823 춘천 32.3
# 2824 춘천 33.6
# 2825 춘천 29.5
# 2826 춘천 27.6
# 2827 춘천 19.3
# 2828 춘천 9.4
# 2829 춘천 7.8
# 2830 춘천 15.8
# 2831 춘천 23.4
# 2832 춘천 26.8
# 2833 춘천 34.0
# 2834 춘천 31.9
# 2835 춘천 35.1
# 2836 춘천 34.6
# 2837 춘천 30.6
# 2838 춘천 26.9
# 2839 춘천 19.7
# 2840 춘천 9.0
# 2841 춘천 7.6
# 2842 춘천 12.0
# 2843 춘천 22.3
# 2844 춘천 29.5
# 2845 춘천 32.2
# 2846 춘천 34.3
# 2847 춘천 35.6
# 2848 춘천 35.9
# 2849 춘천 29.8
# 2850 춘천 26.4
# 2851 춘천 19.3
# 2852 춘천 9.6
# 2853 춘천 7.2
# 2854 춘천 10.1
# 2855 춘천 22.1
# 2856 춘천 28.0
# 2857 춘천 31.6
# 2858 춘천 32.0
# 2859 춘천 34.2
# 2860 춘천 35.7
# 2861 춘천 30.8
# 2862 춘천 28.1
# 2863 춘천 19.0
# 2864 춘천 10.5
# 2865 춘천 10.9
# 2866 춘천 12.3
# 2867 춘천 19.0
# 2868 춘천 28.6
# 2869 춘천 30.8
# 2870 춘천 34.5
# 2871 춘천 34.3
# 2872 춘천 36.3
# 2873 춘천 28.9
# 2874 춘천 26.8
# 2875 춘천 18.4
# 2876 춘천 8.1
# 2877 춘천 8.2
# 2878 춘천 10.9
# 2879 춘천 23.1
# 2880 춘천 29.1
# 2881 춘천 30.6
# 2882 춘천 33.9
# 2883 춘천 37.2
# 2884 춘천 39.5
# 2885 춘천 29.1
# 2886 춘천 24.3
# 2887 춘천 18.8
# 2888 춘천 11.6
# 2889 춘천 8.0
# 2890 춘천 14.1
# 2891 춘천 18.7
# 2892 춘천 28.4
# 2893 춘천 33.5
# 2894 춘천 32.9
# 2895 춘천 36.3
# 2896 춘천 36.3
# 2897 춘천 32.1
# 2898 춘천 26.7
# 2899 춘천 19.7
# 2900 춘천 9.7
# 2901 춘천 11.2
# 2902 춘천 14.5
# 2903 춘천 21.5
# 2904 춘천 24.3
# 2905 춘천 30.1
# 2906 춘천 36.4
# 2907 춘천 33.0
# 2908 춘천 34.6
# 2909 춘천 30.8
# 2910 춘천 24.3
# 2911 춘천 19.5
# 2912 춘천 10.5
# 2913 춘천 12.6
# 2914 춘천 19.9
# 2915 춘천 23.5
# 2916 춘천 29.2
# 2917 춘천 31.2
# 2918 춘천 33.0
# 2919 춘천 36.6
# 2920 춘천 34.3
# 2921 춘천 30.1
# 2922 춘천 28.5
# 2923 춘천 20.6
# 2924 춘천 11.5
# 2925 백령도 30.9
# 2926 백령도 27.6
# 2927 백령도 22.4
# 2928 백령도 16.1
# 2929 백령도 10.5
# 2930 백령도 4.9
# 2931 백령도 8.2
# 2932 백령도 15.6
# 2933 백령도 23.2
# 2934 백령도 27.5
# 2935 백령도 27.3
# 2936 백령도 29.1
# 2937 백령도 32.8
# 2938 백령도 29.9
# 2939 백령도 22.8
# 2940 백령도 15.4
# 2941 백령도 8.7
# 2942 백령도 9.1
# 2943 백령도 8.9
# 2944 백령도 14.6
# 2945 백령도 21.0
# 2946 백령도 23.4
# 2947 백령도 28.0
# 2948 백령도 33.5
# 2949 백령도 30.4
# 2950 백령도 27.4
# 2951 백령도 22.6
# 2952 백령도 13.6
# 2953 백령도 11.7
# 2954 백령도 6.8
# 2955 백령도 9.3
# 2956 백령도 16.6
# 2957 백령도 19.6
# 2958 백령도 26.4
# 2959 백령도 26.0
# 2960 백령도 29.2
# 2961 백령도 29.2
# 2962 백령도 23.8
# 2963 백령도 21.4
# 2964 백령도 16.9
# 2965 백령도 9.6
# 2966 백령도 8.2
# 2967 백령도 15.5
# 2968 백령도 14.5
# 2969 백령도 23.7
# 2970 백령도 24.3
# 2971 백령도 28.8
# 2972 백령도 30.1
# 2973 백령도 32.3
# 2974 백령도 28.0
# 2975 백령도 24.2
# 2976 백령도 17.0
# 2977 백령도 13.8
# 2978 백령도 5.1
# 2979 백령도 6.5
# 2980 백령도 14.2
# 2981 백령도 22.8
# 2982 백령도 28.1
# 2983 백령도 27.3
# 2984 백령도 31.5
# 2985 백령도 31.2
# 2986 백령도 28.6
# 2987 백령도 23.2
# 2988 백령도 20.3
# 2989 백령도 10.0
# 2990 백령도 4.9
# 2991 백령도 8.9
# 2992 백령도 12.9
# 2993 백령도 20.9
# 2994 백령도 23.6
# 2995 백령도 27.2
# 2996 백령도 32.1
# 2997 백령도 32.0
# 2998 백령도 28.6
# 2999 백령도 25.6
# 3000 백령도 19.4
# 3001 백령도 9.8
# 3002 백령도 7.2
# 3003 백령도 11.7
# 3004 백령도 11.9
# 3005 백령도 18.7
# 3006 백령도 26.0
# 3007 백령도 28.0
# 3008 백령도 29.5
# 3009 백령도 30.2
# 3010 백령도 28.1
# 3011 백령도 21.7
# 3012 백령도 16.6
# 3013 백령도 10.8
# 3014 백령도 7.6
# 3015 백령도 7.3
# 3016 백령도 14.1
# 3017 백령도 22.9
# 3018 백령도 22.0
# 3019 백령도 26.2
# 3020 백령도 27.3
# 3021 백령도 30.8
# 3022 백령도 27.5
# 3023 백령도 22.6
# 3024 백령도 15.9
# 3025 백령도 11.7
# 3026 백령도 7.9
# 3027 백령도 10.6
# 3028 백령도 12.9
# 3029 백령도 20.6
# 3030 백령도 26.5
# 3031 백령도 25.8
# 3032 백령도 28.1
# 3033 백령도 30.2
# 3034 백령도 27.2
# 3035 백령도 23.3
# 3036 백령도 19.5
# 3037 백령도 9.5
# 3038 백령도 6.7
# 3039 백령도 14.1
# 3040 백령도 10.8
# 3041 백령도 15.1
# 3042 백령도 23.4
# 3043 백령도 28.5
# 3044 백령도 29.1
# 3045 백령도 29.9
# 3046 백령도 28.3
# 3047 백령도 22.2
# 3048 백령도 16.1
# 3049 백령도 12.1
# 3050 백령도 2.6
# 3051 백령도 7.4
# 3052 백령도 11.0
# 3053 백령도 15.1
# 3054 백령도 25.8
# 3055 백령도 28.1
# 3056 백령도 28.9
# 3057 백령도 28.9
# 3058 백령도 25.4
# 3059 백령도 19.5
# 3060 백령도 18.6
# 3061 백령도 8.0
# 3062 백령도 4.9
# 3063 백령도 7.1
# 3064 백령도 9.7
# 3065 백령도 22.6
# 3066 백령도 24.2
# 3067 백령도 30.0
# 3068 백령도 28.9
# 3069 백령도 31.3
# 3070 백령도 26.7
# 3071 백령도 21.2
# 3072 백령도 14.5
# 3073 백령도 6.6
# 3074 백령도 7.9
# 3075 백령도 6.3
# 3076 백령도 13.0
# 3077 백령도 15.5
# 3078 백령도 24.3
# 3079 백령도 27.8
# 3080 백령도 28.2
# 3081 백령도 30.3
# 3082 백령도 27.7
# 3083 백령도 23.5
# 3084 백령도 15.4
# 3085 백령도 10.8
# 3086 백령도 7.6
# 3087 백령도 11.4
# 3088 백령도 17.3
# 3089 백령도 21.6
# 3090 백령도 23.8
# 3091 백령도 27.8
# 3092 백령도 29.9
# 3093 백령도 33.2
# 3094 백령도 26.8
# 3095 백령도 22.5
# 3096 백령도 16.7
# 3097 백령도 6.8
# 3098 백령도 7.5
# 3099 백령도 8.5
# 3100 백령도 16.5
# 3101 백령도 22.0
# 3102 백령도 25.6
# 3103 백령도 26.6
# 3104 백령도 29.7
# 3105 백령도 30.2
# 3106 백령도 28.2
# 3107 백령도 22.3
# 3108 백령도 17.4
# 3109 백령도 10.3
# 3110 백령도 8.4
# 3111 백령도 9.2
# 3112 백령도 15.7
# 3113 백령도 22.3
# 3114 백령도 26.8
# 3115 백령도 26.9
# 3116 백령도 28.9
# 3117 백령도 31.5
# 3118 백령도 27.4
# 3119 백령도 23.3
# 3120 백령도 16.4
# 3121 백령도 11.3
# 3122 백령도 7.7
# 3123 백령도 8.0
# 3124 백령도 14.8
# 3125 백령도 20.0
# 3126 백령도 24.8
# 3127 백령도 29.0
# 3128 백령도 31.8
# 3129 백령도 31.3
# 3130 백령도 27.4
# 3131 백령도 23.2
# 3132 백령도 17.9
# 3133 백령도 8.8
# 3134 백령도 6.6
# 3135 백령도 6.7
# 3136 백령도 16.6
# 3137 백령도 18.5
# 3138 백령도 21.8
# 3139 백령도 27.8
# 3140 백령도 31.4
# 3141 백령도 32.8
# 3142 백령도 26.2
# 3143 백령도 22.0
# 3144 백령도 16.0
# 3145 백령도 10.9
# 3146 백령도 7.1
# 3147 백령도 10.7
# 3148 백령도 12.8
# 3149 백령도 17.9
# 3150 백령도 24.9
# 3151 백령도 27.1
# 3152 백령도 28.9
# 3153 백령도 31.2
# 3154 백령도 28.1
# 3155 백령도 23.8
# 3156 백령도 18.4
# 3157 백령도 11.3
# 3158 백령도 8.6
# 3159 백령도 11.1
# 3160 백령도 15.4
# 3161 백령도 17.2
# 3162 백령도 22.5
# 3163 백령도 28.0
# 3164 백령도 27.3
# 3165 백령도 30.5
# 3166 백령도 25.6
# 3167 백령도 21.2
# 3168 백령도 18.8
# 3169 백령도 10.5
# 3170 백령도 9.4
# 3171 백령도 12.9
# 3172 백령도 17.1
# 3173 백령도 20.2
# 3174 백령도 23.1
# 3175 백령도 27.1
# 3176 백령도 31.7
# 3177 백령도 28.8
# 3178 백령도 26.7
# 3179 백령도 24.2
# 3180 백령도 19.5
# 3181 백령도 11.5
# 3182 북강릉 33.7
# 3183 북강릉 33.4
# 3184 북강릉 29.7
# 3185 북강릉 26.7
# 3186 북강릉 21.8
# 3187 북강릉 15.7
# 3188 북강릉 10.9
# 3189 북강릉 21.5
# 3190 북강릉 24.8
# 3191 북강릉 27.3
# 3192 북강릉 30.5
# 3193 북강릉 32.9
# 3194 북강릉 30.8
# 3195 북강릉 31.7
# 3196 북강릉 28.2
# 3197 북강릉 25.1
# 3198 북강릉 23.0
# 3199 북강릉 10.8
# 3200 북강릉 13.1
# 3201 북강릉 20.3
# 3202 북강릉 13.6
# 3203 북강릉 19.8
# 3204 북강릉 31.0
# 3205 북강릉 29.6
# 3206 북강릉 35.6
# 3207 북강릉 36.3
# 3208 북강릉 30.6
# 3209 북강릉 23.9
# 3210 북강릉 20.6
# 3211 북강릉 18.1
# 3212 북강릉 6.0
# 3213 북강릉 14.1
# 3214 북강릉 18.5
# 3215 북강릉 25.5
# 3216 북강릉 28.9
# 3217 북강릉 34.1
# 3218 북강릉 31.2
# 3219 북강릉 34.8
# 3220 북강릉 29.4
# 3221 북강릉 25.2
# 3222 북강릉 20.6
# 3223 북강릉 10.9
# 3224 북강릉 5.8
# 3225 북강릉 10.7
# 3226 북강릉 18.9
# 3227 북강릉 28.3
# 3228 북강릉 27.7
# 3229 북강릉 28.9
# 3230 북강릉 35.6
# 3231 북강릉 34.3
# 3232 북강릉 29.3
# 3233 북강릉 25.2
# 3234 북강릉 19.1
# 3235 북강릉 11.1
# 3236 북강릉 11.6
# 3237 북강릉 13.5
# 3238 북강릉 20.4
# 3239 북강릉 22.7
# 3240 북강릉 32.1
# 3241 북강릉 32.0
# 3242 북강릉 34.9
# 3243 북강릉 36.0
# 3244 북강릉 30.2
# 3245 북강릉 25.8
# 3246 북강릉 19.7
# 3247 북강릉 13.5
# 3248 북강릉 12.1
# 3249 북강릉 15.6
# 3250 북강릉 26.5
# 3251 북강릉 26.6
# 3252 북강릉 32.4
# 3253 북강릉 35.4
# 3254 북강릉 35.5
# 3255 북강릉 32.5
# 3256 북강릉 30.3
# 3257 북강릉 25.9
# 3258 북강릉 18.0
# 3259 북강릉 10.8
# 3260 북강릉 13.7
# 3261 북강릉 13.9
# 3262 북강릉 21.6
# 3263 북강릉 30.9
# 3264 북강릉 33.0
# 3265 북강릉 31.5
# 3266 북강릉 36.1
# 3267 북강릉 35.9
# 3268 북강릉 28.7
# 3269 북강릉 26.6
# 3270 북강릉 20.6
# 3271 북강릉 15.7
# 3272 북강릉 12.7
# 3273 북강릉 9.7
# 3274 북강릉 21.2
# 3275 북강릉 28.0
# 3276 북강릉 28.9
# 3277 북강릉 32.0
# 3278 북강릉 33.8
# 3279 북강릉 34.9
# 3280 북강릉 30.2
# 3281 북강릉 24.9
# 3282 북강릉 21.9
# 3283 북강릉 15.2
# 3284 북강릉 12.0
# 3285 북강릉 14.8
# 3286 북강릉 17.2
# 3287 북강릉 30.5
# 3288 북강릉 33.6
# 3289 북강릉 30.7
# 3290 북강릉 33.9
# 3291 북강릉 31.4
# 3292 북강릉 29.0
# 3293 북강릉 23.9
# 3294 북강릉 20.1
# 3295 북강릉 11.7
# 3296 북강릉 13.1
# 3297 북강릉 10.4
# 3298 북강릉 24.6
# 3299 북강릉 31.8
# 3300 북강릉 29.7
# 3301 북강릉 33.6
# 3302 북강릉 34.6
# 3303 북강릉 37.1
# 3304 북강릉 29.0
# 3305 북강릉 24.3
# 3306 북강릉 19.7
# 3307 북강릉 14.0
# 3308 북강릉 12.6
# 3309 북강릉 15.5
# 3310 북강릉 20.8
# 3311 북강릉 24.8
# 3312 북강릉 33.5
# 3313 북강릉 31.9
# 3314 북강릉 34.5
# 3315 북강릉 32.8
# 3316 북강릉 31.2
# 3317 북강릉 23.3
# 3318 북강릉 22.0
# 3319 북강릉 15.8
# 3320 북강릉 10.6
# 3321 북강릉 16.6
# 3322 북강릉 19.4
# 3323 북강릉 25.8
# 3324 북강릉 32.2
# 3325 북강릉 33.2
# 3326 북강릉 31.7
# 3327 북강릉 35.2
# 3328 북강릉 29.0
# 3329 북강릉 25.4
# 3330 북강릉 24.7
# 3331 북강릉 11.8
# 3332 북강릉 13.7
# 3333 북강릉 18.5
# 3334 북강릉 18.9
# 3335 북강릉 24.2
# 3336 북강릉 28.8
# 3337 북강릉 29.7
# 3338 북강릉 32.0
# 3339 북강릉 34.1
# 3340 북강릉 27.5
# 3341 북강릉 31.7
# 3342 북강릉 20.1
# 3343 북강릉 14.4
# 3344 강릉 26.2
# 3345 강릉 19.5
# 3346 강릉 15.1
# 3347 강릉 9.3
# 3348 강릉 13.3
# 3349 강릉 19.4
# 3350 강릉 28.8
# 3351 강릉 29.0
# 3352 강릉 30.4
# 3353 강릉 35.9
# 3354 강릉 36.3
# 3355 강릉 30.8
# 3356 강릉 26.1
# 3357 강릉 23.5
# 3358 강릉 11.4
# 3359 강릉 7.9
# 3360 강릉 16.1
# 3361 강릉 25.4
# 3362 강릉 25.3
# 3363 강릉 31.2
# 3364 강릉 33.9
# 3365 강릉 33.8
# 3366 강릉 33.4
# 3367 강릉 30.5
# 3368 강릉 24.8
# 3369 강릉 23.3
# 3370 강릉 13.1
# 3371 강릉 14.4
# 3372 강릉 14.6
# 3373 강릉 19.3
# 3374 강릉 27.7
# 3375 강릉 31.1
# 3376 강릉 32.6
# 3377 강릉 37.3
# 3378 강릉 34.1
# 3379 강릉 32.2
# 3380 강릉 25.9
# 3381 강릉 23.8
# 3382 강릉 17.1
# 3383 강릉 16.3
# 3384 강릉 13.0
# 3385 강릉 19.0
# 3386 강릉 23.7
# 3387 강릉 32.0
# 3388 강릉 33.6
# 3389 강릉 36.3
# 3390 강릉 32.2
# 3391 강릉 29.0
# 3392 강릉 26.5
# 3393 강릉 21.9
# 3394 강릉 15.6
# 3395 강릉 16.5
# 3396 강릉 11.7
# 3397 강릉 19.0
# 3398 강릉 23.8
# 3399 강릉 33.5
# 3400 강릉 34.0
# 3401 강릉 33.2
# 3402 강릉 33.6
# 3403 강릉 31.8
# 3404 강릉 23.5
# 3405 강릉 18.5
# 3406 강릉 16.6
# 3407 강릉 8.4
# 3408 강릉 11.1
# 3409 강릉 16.9
# 3410 강릉 25.0
# 3411 강릉 30.0
# 3412 강릉 34.2
# 3413 강릉 36.4
# 3414 강릉 36.0
# 3415 강릉 32.0
# 3416 강릉 25.5
# 3417 강릉 17.9
# 3418 강릉 15.1
# 3419 강릉 9.7
# 3420 강릉 12.0
# 3421 강릉 18.0
# 3422 강릉 28.1
# 3423 강릉 27.5
# 3424 강릉 33.5
# 3425 강릉 32.5
# 3426 강릉 34.0
# 3427 강릉 30.5
# 3428 강릉 26.1
# 3429 강릉 19.1
# 3430 강릉 12.6
# 3431 강릉 9.0
# 3432 강릉 14.3
# 3433 강릉 22.6
# 3434 강릉 26.5
# 3435 강릉 30.9
# 3436 강릉 33.9
# 3437 강릉 36.4
# 3438 강릉 33.3
# 3439 강릉 31.5
# 3440 강릉 23.8
# 3441 강릉 24.8
# 3442 강릉 13.5
# 3443 강릉 10.0
# 3444 강릉 6.8
# 3445 강릉 20.9
# 3446 강릉 28.2
# 3447 강릉 29.2
# 3448 강릉 30.5
# 3449 강릉 35.8
# 3450 강릉 33.7
# 3451 강릉 29.9
# 3452 강릉 26.5
# 3453 강릉 26.2
# 3454 강릉 12.9
# 3455 강릉 12.0
# 3456 강릉 16.3
# 3457 강릉 19.0
# 3458 강릉 23.5
# 3459 강릉 27.8
# 3460 강릉 31.5
# 3461 강릉 33.0
# 3462 강릉 36.0
# 3463 강릉 28.3
# 3464 강릉 25.5
# 3465 강릉 19.8
# 3466 강릉 14.5
# 3467 강릉 7.0
# 3468 강릉 15.0
# 3469 강릉 17.7
# 3470 강릉 31.3
# 3471 강릉 32.8
# 3472 강릉 35.4
# 3473 강릉 34.5
# 3474 강릉 35.6
# 3475 강릉 33.3
# 3476 강릉 25.4
# 3477 강릉 20.8
# 3478 강릉 10.7
# 3479 강릉 13.3
# 3480 강릉 8.9
# 3481 강릉 23.3
# 3482 강릉 25.9
# 3483 강릉 30.5
# 3484 강릉 34.2
# 3485 강릉 33.5
# 3486 강릉 37.0
# 3487 강릉 31.4
# 3488 강릉 25.2
# 3489 강릉 19.4
# 3490 강릉 15.0
# 3491 강릉 13.6
# 3492 강릉 8.3
# 3493 강릉 21.6
# 3494 강릉 25.8
# 3495 강릉 32.0
# 3496 강릉 30.8
# 3497 강릉 35.7
# 3498 강릉 35.5
# 3499 강릉 31.7
# 3500 강릉 25.0
# 3501 강릉 22.2
# 3502 강릉 13.5
# 3503 강릉 8.3
# 3504 강릉 8.7
# 3505 강릉 14.5
# 3506 강릉 28.2
# 3507 강릉 30.9
# 3508 강릉 33.3
# 3509 강릉 34.9
# 3510 강릉 34.8
# 3511 강릉 27.7
# 3512 강릉 24.5
# 3513 강릉 19.7
# 3514 강릉 15.0
# 3515 강릉 9.0
# 3516 강릉 12.7
# 3517 강릉 20.6
# 3518 강릉 24.4
# 3519 강릉 30.5
# 3520 강릉 34.5
# 3521 강릉 37.0
# 3522 강릉 36.5
# 3523 강릉 30.9
# 3524 강릉 24.8
# 3525 강릉 21.5
# 3526 강릉 15.7
# 3527 강릉 11.4
# 3528 강릉 8.2
# 3529 강릉 20.0
# 3530 강릉 30.7
# 3531 강릉 29.3
# 3532 강릉 32.6
# 3533 강릉 36.1
# 3534 강릉 34.0
# 3535 강릉 30.3
# 3536 강릉 28.8
# 3537 강릉 20.1
# 3538 강릉 16.7
# 3539 강릉 9.9
# 3540 강릉 8.3
# 3541 강릉 20.8
# 3542 강릉 29.3
# 3543 강릉 33.9
# 3544 강릉 32.0
# 3545 강릉 35.4
# 3546 강릉 33.0
# 3547 강릉 31.3
# 3548 강릉 27.5
# 3549 강릉 19.3
# 3550 강릉 10.7
# 3551 강릉 14.5
# 3552 강릉 17.4
# 3553 강릉 23.2
# 3554 강릉 28.0
# 3555 강릉 30.0
# 3556 강릉 33.5
# 3557 강릉 37.4
# 3558 강릉 37.4
# 3559 강릉 30.4
# 3560 강릉 27.3
# 3561 강릉 20.9
# 3562 강릉 14.6
# 3563 강릉 7.7
# 3564 강릉 17.6
# 3565 강릉 21.5
# 3566 강릉 28.7
# 3567 강릉 30.7
# 3568 강릉 33.7
# 3569 강릉 34.9
# 3570 강릉 35.5
# 3571 강릉 30.7
# 3572 강릉 28.0
# 3573 강릉 20.0
# 3574 강릉 14.5
# 3575 강릉 14.2
# 3576 강릉 11.0
# 3577 강릉 21.0
# 3578 강릉 22.5
# 3579 강릉 27.5
# 3580 강릉 28.4
# 3581 강릉 30.3
# 3582 강릉 34.9
# 3583 강릉 29.2
# 3584 강릉 29.5
# 3585 강릉 22.5
# 3586 강릉 15.9
# 3587 강릉 16.5
# 3588 강릉 9.5
# 3589 강릉 20.0
# 3590 강릉 24.8
# 3591 강릉 33.5
# 3592 강릉 31.5
# 3593 강릉 36.8
# 3594 강릉 33.2
# 3595 강릉 26.6
# 3596 강릉 28.7
# 3597 강릉 24.5
# 3598 강릉 13.1
# 3599 강릉 12.6
# 3600 강릉 10.7
# 3601 강릉 16.7
# 3602 강릉 28.3
# 3603 강릉 30.4
# 3604 강릉 31.2
# 3605 강릉 35.0
# 3606 강릉 34.7
# 3607 강릉 30.5
# 3608 강릉 25.5
# 3609 강릉 19.7
# 3610 강릉 14.8
# 3611 강릉 9.1
# 3612 강릉 9.3
# 3613 강릉 19.0
# 3614 강릉 25.4
# 3615 강릉 31.6
# 3616 강릉 32.9
# 3617 강릉 35.1
# 3618 강릉 33.7
# 3619 강릉 30.7
# 3620 강릉 24.3
# 3621 강릉 21.0
# 3622 강릉 18.9
# 3623 강릉 12.5
# 3624 강릉 15.8
# 3625 강릉 19.7
# 3626 강릉 30.0
# 3627 강릉 30.5
# 3628 강릉 32.1
# 3629 강릉 36.9
# 3630 강릉 34.5
# 3631 강릉 29.3
# 3632 강릉 27.1
# 3633 강릉 20.2
# 3634 강릉 14.5
# 3635 강릉 7.8
# 3636 강릉 11.0
# 3637 강릉 18.5
# 3638 강릉 22.1
# 3639 강릉 32.2
# 3640 강릉 34.6
# 3641 강릉 36.2
# 3642 강릉 32.2
# 3643 강릉 33.2
# 3644 강릉 27.4
# 3645 강릉 21.5
# 3646 강릉 16.5
# 3647 강릉 15.4
# 3648 강릉 11.5
# 3649 강릉 17.5
# 3650 강릉 26.8
# 3651 강릉 34.2
# 3652 강릉 30.1
# 3653 강릉 34.2
# 3654 강릉 37.1
# 3655 강릉 31.0
# 3656 강릉 27.4
# 3657 강릉 22.1
# 3658 강릉 15.0
# 3659 강릉 13.5
# 3660 강릉 17.0
# 3661 강릉 22.2
# 3662 강릉 30.9
# 3663 강릉 33.1
# 3664 강릉 31.8
# 3665 강릉 36.3
# 3666 강릉 34.3
# 3667 강릉 31.3
# 3668 강릉 30.0
# 3669 강릉 23.3
# 3670 강릉 15.2
# 3671 강릉 10.5
# 3672 강릉 13.2
# 3673 강릉 16.8
# 3674 강릉 26.6
# 3675 강릉 29.3
# 3676 강릉 34.7
# 3677 강릉 38.5
# 3678 강릉 35.1
# 3679 강릉 32.5
# 3680 강릉 31.9
# 3681 강릉 21.5
# 3682 강릉 13.0
# 3683 강릉 12.1
# 3684 강릉 11.8
# 3685 강릉 21.7
# 3686 강릉 25.8
# 3687 강릉 32.8
# 3688 강릉 34.1
# 3689 강릉 36.1
# 3690 강릉 34.6
# 3691 강릉 28.7
# 3692 강릉 26.7
# 3693 강릉 26.2
# 3694 강릉 14.2
# 3695 강릉 14.7
# 3696 강릉 11.8
# 3697 강릉 25.8
# 3698 강릉 28.4
# 3699 강릉 30.9
# 3700 강릉 34.0
# 3701 강릉 32.8
# ...
# 53292 거제 28.9
# 53293 거제 25.0
# 53294 거제 20.0
# 53295 거제 14.6
# 53296 거제 11.1
# 53297 거제 16.2
# 53298 거제 17.2
# 53299 거제 22.7
# 53300 거제 29.0
# 53301 거제 28.2
# 53302 거제 34.4
# 53303 거제 33.4
# 53304 거제 29.6
# 53305 거제 25.9
# 53306 거제 20.9
# 53307 거제 17.5
# 53308 거제 13.1
# 53309 거제 12.6
# 53310 거제 18.0
# 53311 거제 22.4
# 53312 거제 30.8
# 53313 거제 28.3
# 53314 거제 34.5
# 53315 거제 32.4
# 53316 거제 31.2
# 53317 거제 27.4
# 53318 거제 19.5
# 53319 거제 17.8
# 53320 거제 17.0
# 53321 거제 18.0
# 53322 거제 18.6
# 53323 거제 20.7
# 53324 거제 33.3
# 53325 거제 29.2
# 53326 거제 31.6
# 53327 거제 34.4
# 53328 거제 29.0
# 53329 거제 26.3
# 53330 거제 25.8
# 53331 거제 17.0
# 53332 거제 13.3
# 53333 거제 14.7
# 53334 거제 18.3
# 53335 거제 22.5
# 53336 거제 28.7
# 53337 거제 30.0
# 53338 거제 30.7
# 53339 거제 30.2
# 53340 거제 29.4
# 53341 거제 27.0
# 53342 거제 21.3
# 53343 거제 15.8
# 53344 거제 8.7
# 53345 거제 13.5
# 53346 거제 20.6
# 53347 거제 23.6
# 53348 거제 30.7
# 53349 거제 31.7
# 53350 거제 34.7
# 53351 거제 31.2
# 53352 거제 28.1
# 53353 거제 24.4
# 53354 거제 16.7
# 53355 거제 14.1
# 53356 거제 14.5
# 53357 거제 13.4
# 53358 거제 20.5
# 53359 거제 23.8
# 53360 거제 27.0
# 53361 거제 31.5
# 53362 거제 32.3
# 53363 거제 32.5
# 53364 거제 28.1
# 53365 거제 27.5
# 53366 거제 20.9
# 53367 거제 15.9
# 53368 거제 13.2
# 53369 거제 13.6
# 53370 거제 17.0
# 53371 거제 25.6
# 53372 거제 31.1
# 53373 거제 30.8
# 53374 거제 31.4
# 53375 거제 37.4
# 53376 거제 31.7
# 53377 거제 26.9
# 53378 거제 19.5
# 53379 거제 13.7
# 53380 거제 11.1
# 53381 거제 11.5
# 53382 거제 20.8
# 53383 거제 24.3
# 53384 거제 27.7
# 53385 거제 30.0
# 53386 거제 33.0
# 53387 거제 35.9
# 53388 거제 28.2
# 53389 거제 24.9
# 53390 거제 23.9
# 53391 거제 15.0
# 53392 거제 10.7
# 53393 거제 12.7
# 53394 거제 17.5
# 53395 거제 23.2
# 53396 거제 26.6
# 53397 거제 29.1
# 53398 거제 35.1
# 53399 거제 34.7
# 53400 거제 31.8
# 53401 거제 26.9
# 53402 거제 20.5
# 53403 거제 17.9
# 53404 거제 10.8
# 53405 거제 14.1
# 53406 거제 17.8
# 53407 거제 24.0
# 53408 거제 28.7
# 53409 거제 30.3
# 53410 거제 33.2
# 53411 거제 33.7
# 53412 거제 29.6
# 53413 거제 24.7
# 53414 거제 20.4
# 53415 거제 16.1
# 53416 거제 12.3
# 53417 거제 16.7
# 53418 거제 17.1
# 53419 거제 23.8
# 53420 거제 27.8
# 53421 거제 31.4
# 53422 거제 31.7
# 53423 거제 32.2
# 53424 거제 29.4
# 53425 거제 27.9
# 53426 거제 20.5
# 53427 거제 18.0
# 53428 거제 12.5
# 53429 거제 15.6
# 53430 거제 17.5
# 53431 거제 24.1
# 53432 거제 30.3
# 53433 거제 31.9
# 53434 거제 33.7
# 53435 거제 34.2
# 53436 거제 29.6
# 53437 거제 26.0
# 53438 거제 20.5
# 53439 거제 19.4
# 53440 거제 14.2
# 53441 거제 17.6
# 53442 거제 18.8
# 53443 거제 26.5
# 53444 거제 28.0
# 53445 거제 30.3
# 53446 거제 33.3
# 53447 거제 31.9
# 53448 거제 28.6
# 53449 거제 24.8
# 53450 거제 22.6
# 53451 거제 18.3
# 53452 거제 15.2
# 53453 거제 15.5
# 53454 거제 19.8
# 53455 거제 23.1
# 53456 거제 27.9
# 53457 거제 31.5
# 53458 거제 35.5
# 53459 거제 37.4
# 53460 거제 31.8
# 53461 거제 26.6
# 53462 거제 21.9
# 53463 거제 17.7
# 53464 거제 10.6
# 53465 거제 11.9
# 53466 거제 21.7
# 53467 거제 24.2
# 53468 거제 28.9
# 53469 거제 31.1
# 53470 거제 32.5
# 53471 거제 33.4
# 53472 거제 31.1
# 53473 거제 26.7
# 53474 거제 19.9
# 53475 거제 16.4
# 53476 거제 12.8
# 53477 거제 17.9
# 53478 거제 18.8
# 53479 거제 23.9
# 53480 거제 27.6
# 53481 거제 30.3
# 53482 거제 33.7
# 53483 거제 30.8
# 53484 거제 31.8
# 53485 거제 25.5
# 53486 거제 23.0
# 53487 거제 16.7
# 53488 거제 11.8
# 53489 거제 15.6
# 53490 거제 18.0
# 53491 거제 24.9
# 53492 거제 29.6
# 53493 거제 30.5
# 53494 거제 29.7
# 53495 거제 31.7
# 53496 거제 29.2
# 53497 거제 25.3
# 53498 거제 22.0
# 53499 거제 15.0
# 53500 거제 11.6
# 53501 거제 13.7
# 53502 거제 19.4
# 53503 거제 25.4
# 53504 거제 28.0
# 53505 거제 29.6
# 53506 거제 38.6
# 53507 거제 34.6
# 53508 거제 34.2
# 53509 거제 26.5
# 53510 거제 22.6
# 53511 거제 17.4
# 53512 거제 13.4
# 53513 거제 13.3
# 53514 거제 18.9
# 53515 거제 24.7
# 53516 거제 27.3
# 53517 거제 30.7
# 53518 거제 32.8
# 53519 거제 35.2
# 53520 거제 30.5
# 53521 거제 27.3
# 53522 거제 20.2
# 53523 거제 11.4
# 53524 거제 16.4
# 53525 거제 18.3
# 53526 거제 16.5
# 53527 거제 24.6
# 53528 거제 33.1
# 53529 거제 29.7
# 53530 거제 34.6
# 53531 거제 34.2
# 53532 거제 29.3
# 53533 거제 25.4
# 53534 거제 21.2
# 53535 거제 15.5
# 53536 거제 16.9
# 53537 거제 16.7
# 53538 거제 19.3
# 53539 거제 23.2
# 53540 거제 25.9
# 53541 거제 31.7
# 53542 거제 34.4
# 53543 거제 33.3
# 53544 거제 32.3
# 53545 거제 27.5
# 53546 거제 22.2
# 53547 거제 17.4
# 53548 거제 13.1
# 53549 거제 19.4
# 53550 거제 23.1
# 53551 거제 27.6
# 53552 거제 27.8
# 53553 거제 29.6
# 53554 거제 29.8
# 53555 거제 30.7
# 53556 거제 30.9
# 53557 거제 26.7
# 53558 거제 20.9
# 53559 거제 16.6
# 53560 거제 12.7
# 53561 거제 16.4
# 53562 거제 20.5
# 53563 거제 27.4
# 53564 거제 26.9
# 53565 거제 31.0
# 53566 거제 31.0
# 53567 거제 31.5
# 53568 거제 30.8
# 53569 거제 27.3
# 53570 거제 20.2
# 53571 거제 13.6
# 53572 거제 13.5
# 53573 거제 12.6
# 53574 거제 17.2
# 53575 거제 21.6
# 53576 거제 32.5
# 53577 거제 31.0
# 53578 거제 31.9
# 53579 거제 32.6
# 53580 거제 29.7
# 53581 거제 25.4
# 53582 거제 21.0
# 53583 거제 15.7
# 53584 거제 10.7
# 53585 거제 15.8
# 53586 거제 21.7
# 53587 거제 24.8
# 53588 거제 27.8
# 53589 거제 28.0
# 53590 거제 32.9
# 53591 거제 34.4
# 53592 거제 28.8
# 53593 거제 24.7
# 53594 거제 21.2
# 53595 거제 14.1
# 53596 거제 17.6
# 53597 거제 14.6
# 53598 거제 20.5
# 53599 거제 23.8
# 53600 거제 28.0
# 53601 거제 31.7
# 53602 거제 32.0
# 53603 거제 33.0
# 53604 거제 31.7
# 53605 거제 26.2
# 53606 거제 19.2
# 53607 거제 15.3
# 53608 거제 12.6
# 53609 거제 13.0
# 53610 거제 17.7
# 53611 거제 24.7
# 53612 거제 26.2
# 53613 거제 29.2
# 53614 거제 30.5
# 53615 거제 31.7
# 53616 거제 31.5
# 53617 거제 25.3
# 53618 거제 23.7
# 53619 거제 15.6
# 53620 거제 11.6
# 53621 거제 18.0
# 53622 거제 21.1
# 53623 거제 25.1
# 53624 거제 27.7
# 53625 거제 30.7
# 53626 거제 34.7
# 53627 거제 34.0
# 53628 거제 30.2
# 53629 거제 24.8
# 53630 거제 22.2
# 53631 거제 17.7
# 53632 거제 11.8
# 53633 거제 12.0
# 53634 거제 19.8
# 53635 거제 23.6
# 53636 거제 28.2
# 53637 거제 33.5
# 53638 거제 34.7
# 53639 거제 33.5
# 53640 거제 31.8
# 53641 거제 26.8
# 53642 거제 24.0
# 53643 거제 14.8
# 53644 거제 12.5
# 53645 거제 15.8
# 53646 거제 17.6
# 53647 거제 22.0
# 53648 거제 27.2
# 53649 거제 30.7
# 53650 거제 31.6
# 53651 거제 35.2
# 53652 거제 29.8
# 53653 거제 27.1
# 53654 거제 22.2
# 53655 거제 15.8
# 53656 거제 12.5
# 53657 거제 16.3
# 53658 거제 19.1
# 53659 거제 23.2
# 53660 거제 29.8
# 53661 거제 28.7
# 53662 거제 34.4
# 53663 거제 33.5
# 53664 거제 30.5
# 53665 거제 27.3
# 53666 거제 20.5
# 53667 거제 15.6
# 53668 거제 12.7
# 53669 거제 12.5
# 53670 거제 18.2
# 53671 거제 23.3
# 53672 거제 31.0
# 53673 거제 31.1
# 53674 거제 34.2
# 53675 거제 32.2
# 53676 거제 30.4
# 53677 거제 27.1
# 53678 거제 20.0
# 53679 거제 17.5
# 53680 거제 12.3
# 53681 거제 18.2
# 53682 거제 20.3
# 53683 거제 25.5
# 53684 거제 29.9
# 53685 거제 31.3
# 53686 거제 30.3
# 53687 거제 32.8
# 53688 거제 30.7
# 53689 거제 26.1
# 53690 거제 23.9
# 53691 거제 17.5
# 53692 거제 16.7
# 53693 거제 18.7
# 53694 거제 17.1
# 53695 거제 21.2
# 53696 거제 29.8
# 53697 거제 31.5
# 53698 거제 32.9
# 53699 거제 35.4
# 53700 거제 33.5
# 53701 거제 26.8
# 53702 거제 20.1
# 53703 거제 19.2
# 53704 거제 7.3
# 53705 거제 17.9
# 53706 거제 20.7
# 53707 거제 20.8
# 53708 거제 27.2
# 53709 거제 29.1
# 53710 거제 33.4
# 53711 거제 32.3
# 53712 거제 34.0
# 53713 거제 26.4
# 53714 거제 25.8
# 53715 거제 13.6
# 53716 거제 12.1
# 53717 거제 15.4
# 53718 거제 19.2
# 53719 거제 25.3
# 53720 거제 29.6
# 53721 거제 28.8
# 53722 거제 35.8
# 53723 거제 34.5
# 53724 거제 29.9
# 53725 거제 25.9
# 53726 거제 18.2
# 53727 거제 15.8
# 53728 거제 13.6
# 53729 거제 16.5
# 53730 거제 21.8
# 53731 거제 23.2
# 53732 거제 30.6
# 53733 거제 30.6
# 53734 거제 33.3
# 53735 거제 36.7
# 53736 거제 31.8
# 53737 거제 27.6
# 53738 거제 23.2
# 53739 거제 14.5
# 53740 거제 16.0
# 53741 거제 17.7
# 53742 거제 23.2
# 53743 거제 25.6
# 53744 거제 31.3
# 53745 거제 29.9
# 53746 거제 34.2
# 53747 거제 32.4
# 53748 거제 30.9
# 53749 거제 26.3
# 53750 거제 20.3
# 53751 거제 14.1
# 53752 거제 14.1
# 53753 거제 14.3
# 53754 거제 22.0
# 53755 거제 26.4
# 53756 거제 33.0
# 53757 거제 30.6
# 53758 거제 33.3
# 53759 거제 35.9
# 53760 거제 28.9
# 53761 거제 27.1
# 53762 거제 23.8
# 53763 거제 16.6
# 53764 거제 15.2
# 53765 거제 17.9
# 53766 거제 22.2
# 53767 거제 25.9
# 53768 거제 30.5
# 53769 거제 29.3
# 53770 거제 35.3
# 53771 거제 36.9
# 53772 거제 30.4
# 53773 거제 28.8
# 53774 거제 20.2
# 53775 거제 19.4
# 53776 거제 14.0
# 53777 거제 16.8
# 53778 거제 19.2
# 53779 거제 26.3
# 53780 거제 34.4
# 53781 거제 31.9
# 53782 거제 35.4
# 53783 거제 37.0
# 53784 거제 29.9
# 53785 거제 29.5
# 53786 거제 23.6
# 53787 거제 14.0
# 53788 거제 13.5
# 53789 거제 14.9
# 53790 거제 24.2
# 53791 거제 27.9
# 53792 거제 28.4
# 53793 거제 33.2
# 53794 거제 37.8
# 53795 거제 36.5
# 53796 거제 30.7
# 53797 거제 27.0
# 53798 거제 21.3
# 53799 거제 19.0
# 53800 거제 13.0
# 53801 거제 16.8
# 53802 거제 21.6
# 53803 거제 25.4
# 53804 거제 30.3
# 53805 거제 32.0
# 53806 거제 32.4
# 53807 거제 35.8
# 53808 거제 33.6
# 53809 거제 29.9
# 53810 거제 24.0
# 53811 거제 16.0
# 53812 거제 19.3
# 53813 거제 17.5
# 53814 거제 20.6
# 53815 거제 22.4
# 53816 거제 26.5
# 53817 거제 32.2
# 53818 거제 29.9
# 53819 거제 34.5
# 53820 거제 29.4
# 53821 거제 25.6
# 53822 거제 23.1
# 53823 거제 12.8
# 53824 거제 15.6
# 53825 거제 19.2
# 53826 거제 22.3
# 53827 거제 25.2
# 53828 거제 27.5
# 53829 거제 29.4
# 53830 거제 32.2
# 53831 거제 34.0
# 53832 거제 29.3
# 53833 거제 28.9
# 53834 거제 20.9
# 53835 거제 16.4
# 53836 남해 11.2
# 53837 남해 3.2
# 53838 남해 17.0
# 53839 남해 10.8
# 53840 남해 18.8
# 53841 남해 27.8
# 53842 남해 27.4
# 53843 남해 27.1
# 53844 남해 23.3
# 53845 남해 22.2
# 53846 남해 9.2
# 53847 남해 13.7
# 53848 남해 14.4
# 53849 남해 21.2
# 53850 남해 25.3
# 53851 남해 26.8
# 53852 남해 33.5
# 53853 남해 33.6
# 53854 남해 34.9
# 53855 남해 29.5
# 53856 남해 26.6
# 53857 남해 20.8
# 53858 남해 13.8
# 53859 남해 11.4
# 53860 남해 14.8
# 53861 남해 18.8
# 53862 남해 22.5
# 53863 남해 26.4
# 53864 남해 30.2
# 53865 남해 30.6
# 53866 남해 32.8
# 53867 남해 31.0
# 53868 남해 25.2
# 53869 남해 21.9
# 53870 남해 13.2
# 53871 남해 12.0
# 53872 남해 14.4
# 53873 남해 16.8
# 53874 남해 22.9
# 53875 남해 26.8
# 53876 남해 30.3
# 53877 남해 32.2
# 53878 남해 35.6
# 53879 남해 31.8
# 53880 남해 26.8
# 53881 남해 20.6
# 53882 남해 17.7
# 53883 남해 13.0
# 53884 남해 14.0
# 53885 남해 18.7
# 53886 남해 23.4
# 53887 남해 27.0
# 53888 남해 29.9
# 53889 남해 31.6
# 53890 남해 32.6
# 53891 남해 29.6
# 53892 남해 25.8
# 53893 남해 21.0
# 53894 남해 15.1
# 53895 남해 9.5
# 53896 남해 18.6
# 53897 남해 17.8
# 53898 남해 22.3
# 53899 남해 27.8
# 53900 남해 28.0
# 53901 남해 34.4
# 53902 남해 34.1
# 53903 남해 31.4
# 53904 남해 27.7
# 53905 남해 22.4
# 53906 남해 17.7
# 53907 남해 12.0
# 53908 남해 13.9
# 53909 남해 18.4
# 53910 남해 23.4
# 53911 남해 31.4
# 53912 남해 31.9
# 53913 남해 35.2
# 53914 남해 33.2
# 53915 남해 31.8
# 53916 남해 29.0
# 53917 남해 20.6
# 53918 남해 19.4
# 53919 남해 18.3
# 53920 남해 19.4
# 53921 남해 19.4
# 53922 남해 23.0
# 53923 남해 33.7
# 53924 남해 29.6
# 53925 남해 32.3
# 53926 남해 33.4
# 53927 남해 28.8
# 53928 남해 26.6
# 53929 남해 25.1
# 53930 남해 15.2
# 53931 남해 11.3
# 53932 남해 14.6
# 53933 남해 18.5
# 53934 남해 22.0
# 53935 남해 29.3
# 53936 남해 30.5
# 53937 남해 30.7
# 53938 남해 29.8
# 53939 남해 29.5
# 53940 남해 26.4
# 53941 남해 20.6
# 53942 남해 14.8
# 53943 남해 8.2
# 53944 남해 13.4
# 53945 남해 22.4
# 53946 남해 24.4
# 53947 남해 31.5
# 53948 남해 32.5
# 53949 남해 34.4
# 53950 남해 32.7
# 53951 남해 28.7
# 53952 남해 26.3
# 53953 남해 17.4
# 53954 남해 13.8
# 53955 남해 14.3
# 53956 남해 15.6
# 53957 남해 21.1
# 53958 남해 25.6
# 53959 남해 29.1
# 53960 남해 32.9
# 53961 남해 33.0
# 53962 남해 34.0
# 53963 남해 30.3
# 53964 남해 28.5
# 53965 남해 21.8
# 53966 남해 14.6
# 53967 남해 14.2
# 53968 남해 14.6
# 53969 남해 20.2
# 53970 남해 26.4
# 53971 남해 31.1
# 53972 남해 31.1
# 53973 남해 33.8
# 53974 남해 37.6
# 53975 남해 32.0
# 53976 남해 28.1
# 53977 남해 21.0
# 53978 남해 15.0
# 53979 남해 12.2
# 53980 남해 11.6
# 53981 남해 21.2
# 53982 남해 23.6
# 53983 남해 27.8
# 53984 남해 31.5
# 53985 남해 34.6
# 53986 남해 36.0
# 53987 남해 29.7
# 53988 남해 25.5
# 53989 남해 24.1
# 53990 남해 17.2
# 53991 남해 10.5
# 53992 남해 14.7
# 53993 남해 18.7
# 53994 남해 24.5
# 53995 남해 28.1
# 53996 남해 29.7
# 53997 남해 36.0
# 53998 남해 34.8
# 53999 남해 33.6
# 54000 남해 27.5
# 54001 남해 20.8
# 54002 남해 17.1
# 54003 남해 12.7
# 54004 남해 15.5
# 54005 남해 18.8
# 54006 남해 25.5
# 54007 남해 29.3
# 54008 남해 31.7
# 54009 남해 33.6
# 54010 남해 35.0
# 54011 남해 30.9
# 54012 남해 25.7
# 54013 남해 20.2
# 54014 남해 16.1
# 54015 남해 13.1
# 54016 남해 19.7
# 54017 남해 18.6
# 54018 남해 24.6
# 54019 남해 28.5
# 54020 남해 31.5
# 54021 남해 32.0
# 54022 남해 32.6
# 54023 남해 30.6
# 54024 남해 28.6
# 54025 남해 21.5
# 54026 남해 18.7
# 54027 남해 14.3
# 54028 남해 16.1
# 54029 남해 16.6
# 54030 남해 25.5
# 54031 남해 30.9
# 54032 남해 32.5
# 54033 남해 34.6
# 54034 남해 35.0
# 54035 남해 30.9
# 54036 남해 26.9
# 54037 남해 22.4
# 54038 남해 20.2
# 54039 남해 12.2
# 54040 남해 18.7
# 54041 남해 21.6
# 54042 남해 26.4
# 54043 남해 29.8
# 54044 남해 30.7
# 54045 남해 33.5
# 54046 남해 32.9
# 54047 남해 29.5
# 54048 남해 26.0
# 54049 남해 23.1
# 54050 남해 20.2
# 54051 남해 14.0
# 54052 남해 13.8
# 54053 남해 19.5
# 54054 남해 25.1
# 54055 남해 28.5
# 54056 남해 32.0
# 54057 남해 36.6
# 54058 남해 37.0
# 54059 남해 32.2
# 54060 남해 27.4
# 54061 남해 22.6
# 54062 남해 18.5
# 54063 남해 8.7
# 54064 남해 11.2
# 54065 남해 22.4
# 54066 남해 23.9
# 54067 남해 29.5
# 54068 남해 32.1
# 54069 남해 32.8
# 54070 남해 33.3
# 54071 남해 31.5
# 54072 남해 26.6
# 54073 남해 20.3
# 54074 남해 16.7
# 54075 남해 12.3
# 54076 남해 18.0
# 54077 남해 20.2
# 54078 남해 25.9
# 54079 남해 28.5
# 54080 남해 30.4
# 54081 남해 33.8
# 54082 남해 32.1
# 54083 남해 31.4
# 54084 남해 24.9
# 54085 남해 19.6
# 54086 남해 15.4
# 54087 남해 11.2
# 54088 남해 18.3
# 54089 남해 17.8
# 54090 남해 26.4
# 54091 남해 28.3
# 54092 남해 30.4
# 54093 남해 30.3
# 54094 남해 31.0
# 54095 남해 28.8
# 54096 남해 25.5
# 54097 남해 22.4
# 54098 남해 15.0
# 54099 남해 13.0
# 54100 남해 13.5
# 54101 남해 19.0
# 54102 남해 25.6
# 54103 남해 27.8
# 54104 남해 31.3
# 54105 남해 37.8
# 54106 남해 34.3
# 54107 남해 34.1
# 54108 남해 26.2
# 54109 남해 22.8
# 54110 남해 17.9
# 54111 남해 13.2
# 54112 남해 13.7
# 54113 남해 18.6
# 54114 남해 24.2
# 54115 남해 27.3
# 54116 남해 29.2
# 54117 남해 32.6
# 54118 남해 34.6
# 54119 남해 31.4
# 54120 남해 27.0
# 54121 남해 20.3
# 54122 남해 11.6
# 54123 남해 14.4
# 54124 남해 21.0
# 54125 남해 16.7
# 54126 남해 26.1
# 54127 남해 30.3
# 54128 남해 29.2
# 54129 남해 34.6
# 54130 남해 34.8
# 54131 남해 29.4
# 54132 남해 26.8
# 54133 남해 20.4
# 54134 남해 15.0
# 54135 남해 16.2
# 54136 남해 17.8
# 54137 남해 19.3
# 54138 남해 24.8
# 54139 남해 29.2
# 54140 남해 32.2
# 54141 남해 34.8
# 54142 남해 34.0
# 54143 남해 33.5
# 54144 남해 27.5
# 54145 남해 22.1
# 54146 남해 16.8
# 54147 남해 11.4
# 54148 남해 21.5
# 54149 남해 24.4
# 54150 남해 27.7
# 54151 남해 28.9
# 54152 남해 29.8
# 54153 남해 32.6
# 54154 남해 32.7
# 54155 남해 31.9
# 54156 남해 27.1
# 54157 남해 22.3
# 54158 남해 17.5
# 54159 남해 12.2
# 54160 남해 16.4
# 54161 남해 18.2
# 54162 남해 27.7
# 54163 남해 26.7
# 54164 남해 31.0
# 54165 남해 30.2
# 54166 남해 30.9
# 54167 남해 29.4
# 54168 남해 28.8
# 54169 남해 20.6
# 54170 남해 14.3
# 54171 남해 13.2
# 54172 남해 13.0
# 54173 남해 18.8
# 54174 남해 24.8
# 54175 남해 33.5
# 54176 남해 32.8
# 54177 남해 33.5
# 54178 남해 35.1
# 54179 남해 32.1
# 54180 남해 26.8
# 54181 남해 21.1
# 54182 남해 15.7
# 54183 남해 9.1
# 54184 남해 16.8
# 54185 남해 22.2
# 54186 남해 25.6
# 54187 남해 29.2
# 54188 남해 30.3
# 54189 남해 34.7
# 54190 남해 35.3
# 54191 남해 30.6
# 54192 남해 25.7
# 54193 남해 22.2
# 54194 남해 14.1
# 54195 남해 18.5
# 54196 남해 15.1
# 54197 남해 22.1
# 54198 남해 25.7
# 54199 남해 28.8
# 54200 남해 31.8
# 54201 남해 34.0
# 54202 남해 34.7
# 54203 남해 33.5
# 54204 남해 27.2
# 54205 남해 19.8
# 54206 남해 15.1
# 54207 남해 12.3
# 54208 남해 13.1
# 54209 남해 19.0
# 54210 남해 25.6
# 54211 남해 26.7
# 54212 남해 28.6
# 54213 남해 33.5
# 54214 남해 34.9
# 54215 남해 33.2
# 54216 남해 27.5
# 54217 남해 24.6
# 54218 남해 16.2
# 54219 남해 12.5
# 54220 남해 19.3
# 54221 남해 23.1
# 54222 남해 28.1
# 54223 남해 31.0
# 54224 남해 32.5
# 54225 남해 37.2
# 54226 남해 36.0
# 54227 남해 31.6
# 54228 남해 26.7
# 54229 남해 22.7
# 54230 남해 16.0
# 54231 남해 11.3
# 54232 남해 11.0
# 54233 남해 20.1
# 54234 남해 26.3
# 54235 남해 28.7
# 54236 남해 32.7
# 54237 남해 34.0
# 54238 남해 33.0
# 54239 남해 32.5
# 54240 남해 28.1
# 54241 남해 23.0
# 54242 남해 14.3
# 54243 남해 11.3
# 54244 남해 16.3
# 54245 남해 18.8
# 54246 남해 25.7
# 54247 남해 28.2
# 54248 남해 30.6
# 54249 남해 33.0
# 54250 남해 35.5
# 54251 남해 30.0
# 54252 남해 27.7
# 54253 남해 23.1
# 54254 남해 15.6
# 54255 남해 12.1
# 54256 남해 16.7
# 54257 남해 19.7
# 54258 남해 25.3
# 54259 남해 30.6
# 54260 남해 29.3
# 54261 남해 35.0
# 54262 남해 34.5
# 54263 남해 30.3
# 54264 남해 27.3
# 54265 남해 21.0
# 54266 남해 16.2
# 54267 남해 13.3
# 54268 남해 13.6
# 54269 남해 18.1
# 54270 남해 25.3
# 54271 남해 31.4
# 54272 남해 30.8
# 54273 남해 34.5
# 54274 남해 33.7
# 54275 남해 31.9
# 54276 남해 27.5
# 54277 남해 20.9
# 54278 남해 17.7
# 54279 남해 12.8
# 54280 남해 18.9
# 54281 남해 20.6
# 54282 남해 26.5
# 54283 남해 30.5
# 54284 남해 32.6
# 54285 남해 33.4
# 54286 남해 33.2
# 54287 남해 31.0
# 54288 남해 27.5
# 54289 남해 23.7
# 54290 남해 16.8
# 54291 남해 16.6
# 54292 남해 17.9
# 54293 남해 21.4
# 54294 남해 24.1
# 54295 남해 30.5
# 54296 남해 32.1
# 54297 남해 33.1
# 54298 남해 34.9
# 54299 남해 32.8
# 54300 남해 26.2
# 54301 남해 19.7
# 54302 남해 17.1
# 54303 남해 6.7
# 54304 남해 19.0
# 54305 남해 20.8
# 54306 남해 24.7
# 54307 남해 28.4
# 54308 남해 31.3
# 54309 남해 33.5
# 54310 남해 33.3
# 54311 남해 34.6
# 54312 남해 25.9
# 54313 남해 24.7
# 54314 남해 13.8
# 54315 남해 10.7
# 54316 남해 14.6
# 54317 남해 21.3
# 54318 남해 24.7
# 54319 남해 30.4
# 54320 남해 29.1
# 54321 남해 35.1
# 54322 남해 35.5
# 54323 남해 29.7
# 54324 남해 25.7
# 54325 남해 17.3
# 54326 남해 12.6
# 54327 남해 12.5
# 54328 남해 16.6
# 54329 남해 21.4
# 54330 남해 23.9
# 54331 남해 31.5
# 54332 남해 30.3
# 54333 남해 34.7
# 54334 남해 37.7
# 54335 남해 31.6
# 54336 남해 27.7
# 54337 남해 23.3
# 54338 남해 13.7
# 54339 남해 15.2
# 54340 남해 21.0
# 54341 남해 23.4
# 54342 남해 26.6
# 54343 남해 32.3
# 54344 남해 30.3
# 54345 남해 34.5
# 54346 남해 33.5
# 54347 남해 30.4
# 54348 남해 25.8
# 54349 남해 19.9
# 54350 남해 13.3
# 54351 남해 14.1
# 54352 남해 13.7
# 54353 남해 22.7
# 54354 남해 28.7
# 54355 남해 33.0
# 54356 남해 30.6
# 54357 남해 34.1
# 54358 남해 34.7
# 54359 남해 29.8
# 54360 남해 26.1
# 54361 남해 22.2
# 54362 남해 15.2
# 54363 남해 15.6
# 54364 남해 17.4
# 54365 남해 21.5
# 54366 남해 26.7
# 54367 남해 31.6
# 54368 남해 30.3
# 54369 남해 35.5
# 54370 남해 37.5
# 54371 남해 30.6
# 54372 남해 29.0
# 54373 남해 20.6
# 54374 남해 20.5
# 54375 남해 15.1
# 54376 남해 15.5
# 54377 남해 19.0
# 54378 남해 28.1
# 54379 남해 34.1
# 54380 남해 32.4
# 54381 남해 35.9
# 54382 남해 36.9
# 54383 남해 29.7
# 54384 남해 28.6
# 54385 남해 22.6
# 54386 남해 13.0
# 54387 남해 13.8
# 54388 남해 15.4
# 54389 남해 23.1
# 54390 남해 27.2
# 54391 남해 28.9
# 54392 남해 34.1
# 54393 남해 36.8
# 54394 남해 36.6
# 54395 남해 31.4
# 54396 남해 26.6
# 54397 남해 20.1
# 54398 남해 16.3
# 54399 남해 12.0
# 54400 남해 16.3
# 54401 남해 21.4
# 54402 남해 25.1
# 54403 남해 31.5
# 54404 남해 32.1
# 54405 남해 32.8
# 54406 남해 35.2
# 54407 남해 31.0
# 54408 남해 28.5
# 54409 남해 22.9
# 54410 남해 16.6
# 54411 남해 18.6
# 54412 남해 18.4
# 54413 남해 21.2
# 54414 남해 23.4
# 54415 남해 27.7
# 54416 남해 31.5
# 54417 남해 31.6
# 54418 남해 34.6
# 54419 남해 29.7
# 54420 남해 25.7
# 54421 남해 23.2
# 54422 남해 12.3
# 54423 남해 15.6
# 54424 남해 22.1
# 54425 남해 22.0
# 54426 남해 25.0
# 54427 남해 28.3
# 54428 남해 29.7
# 54429 남해 33.0
# 54430 남해 35.5
# 54431 남해 30.1
# 54432 남해 28.9
# 54433 남해 21.7
# 54434 남해 14.9

# %% [markdown]
# #### 6.가공된 파일 신규 저장하기

# %%
# 가공된 데이터 신규 파일로 저장하기
#file = 'c:/python/gachon/2022_1_statistics/data/weather_data2.csv'    
file = 'data/weather_data2.csv' 
df.to_csv(file, encoding='cp949', mode='w', index=True)


file = 'data/weather_group_max.csv'    
df2.to_csv(file, encoding='cp949', mode='w', index=True)

# %% [markdown]
# --------------------------

# %% [markdown]
# ### 4-2. 데이터 시각화하기: 그래프

# %% [markdown]
# ### [실습] : 지점별 평균기온 그래프

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# 한글출력 설정
matplotlib.rcParams['font.family'] = 'Malgun Gothic'

# 1. 데이터 가져오기
file = 'data/weather_data2.csv'   
df = pd.read_csv(file, encoding='CP949', engine='python')

# %%
# 2. 지점별 평균기온 데이터 추출하기: reset_index()
data = df.groupby('지점명')['평균기온'].agg(**{'평균기온':'mean'})
# print(data)

# 3. 그래프로 시각화하기 
plt.figure(figsize=(15,5))     # 그래프 크기
plt.title('지점명 평균기온 통계') #제목
plt.legend(['평균기온'])  # 범례,기본 위치 : loc='upper left'
plt.xlabel('지점')        # x축 레이블
plt.ylabel('평균기온')    # y축 레이블
plt.xticks(rotation=45)  # x축 레이블 기울이기
plt.grid()               # 격자 표시
plt.plot(data, 'o', linestyle='solid', c='r')  
plt.show()

# %% [markdown]
# ### [실습] : '제주' 지점의 년도별 평균기온을  선 그래프로 나타내기

# %%
# 2. '제주'지점 년도별 평균기온 데이터 추출하기: reset_index()
# data = df.query(" 지점명 == '제주' ")
# data = data.groupby('년도')['평균기온'].agg(**{'평균기온':'mean'}).reset_index()

data = df.groupby(['지점명','년도'])['평균기온'].agg(**{'평균기온':'mean'}).reset_index()
data = data.query(" 지점명 == '제주' ")

X = data['년도']
Y = data['평균기온']

# 3. 그래프로 시각화하기 
plt.figure(figsize=(15,5))
plt.title("'제주'지점 년도별 평균기온 통계", fontsize=15) #제목
plt.xlabel('년도')        # x축 레이블
plt.ylabel('평균기온')    # y축 레이블             
plt.legend(['평균기온'])  #범례,기본 위치 : loc='upper left'
plt.xticks(rotation=45)  # x축 레이블 기울이기
plt.grid()               # 격자 표시
plt.plot(X, Y, 'o', linestyle='solid', c='r')  
plt.show()

# %% [markdown]
# ### [실습]: 제주의 평균기온, 최고기온, 최저기온 통계를 그래프로 나타내기

# %%
# 2. '제주'지점 년도별 평균기온, 최고기온, 최저기온 데이터 추출하기: reset_index()
data = df.groupby(['지점명','년도'])['평균기온'].agg(**{'평균기온':'mean'}).reset_index()
data = data.query(" 지점명 == '제주' ")
X  = data['년도']
Y1 = data['평균기온']

data = df.groupby(['지점명','년도'])['최고기온'].agg(**{'최고기온':'max'}).reset_index()
data = data.query(" 지점명 == '제주' ")
Y2 = data['최고기온']
data = df.groupby(['지점명','년도'])['최저기온'].agg(**{'최저기온':'min'}).reset_index()
data = data.query(" 지점명 == '제주' ")
Y3 = data['최저기온']

# 3. 그래프로 시각화하기 
plt.figure(figsize=(20,5))
plt.title('제주 기온 통계', fontsize=15) #제목
plt.legend(['평균기온','최고기온','최저기온'])  #범례,기본 위치 : loc='upper left'
plt.xlabel('년도')        # x축 레이블
plt.ylabel('기온')    # y축 레이블 
plt.xticks(rotation=45)  # x축 레이블 기울이기
plt.grid()               # 격자 표시

plt.plot(X, Y1, 'o', linestyle='solid', c='r')  # 선그래프
plt.plot(X, Y2, 'o', linestyle='solid', c='g')  # 선그래프
plt.plot(X, Y3, 'o', linestyle='solid', c='b')  # 선그래프
plt.show()

# %% [markdown]
# ### [실습]: 제주의 최고기온(선그래프),평균기온(막대그래프)을 혼합 그래프로 나타내기

# %%
# 3. 그래프로 시각화하기 
plt.figure(figsize=(20,5))
plt.title('제주 기온 통계', fontsize=15)         #제목
plt.legend(['최고기온','평균기온']) #범례,기본 위치 : loc='upper left'
plt.xlabel('년도')                 # x축 레이블
plt.ylabel('기온')                 # y축 레이블  
plt.xticks(rotation=45)           # x축 레이블 기울이기
plt.grid()                        # 격자 표시

plt.bar(X, Y1)  # 막대 그래프
plt.plot(X, Y2, 'o', linestyle='solid', c='r')  # 선그래프
plt.show()

# %%
df
# Out:
#        Unnamed: 0   지점 지점명          일시    년도  평균기온  최고기온  최저기온  평균현지기압  \
# 0               0   90  속초  1968-01-01  1968  -0.7  11.4 -11.4  1018.2
# 1               1   90  속초  1968-02-01  1968  -2.1   9.7  -9.9  1022.8
# 2               2   90  속초  1968-03-01  1968   5.9  20.5  -3.2  1016.1
# 3               3   90  속초  1968-04-01  1968  10.5  21.4   4.0  1019.4
# 4               4   90  속초  1968-05-01  1968  14.6  24.5   9.3  1011.7
# ...           ...  ...  ..         ...   ...   ...   ...   ...     ...
# 54430       54430  295  남해  2021-08-01  2021  26.1  35.5  20.7  1003.2
# 54431       54431  295  남해  2021-09-01  2021  22.2  30.1  16.3  1008.1
# 54432       54432  295  남해  2021-10-01  2021  17.2  28.9   4.7  1015.3
# 54433       54433  295  남해  2021-11-01  2021  10.7  21.7   1.4  1014.2
# 54434       54434  295  남해  2021-12-01  2021   4.9  14.9  -8.0  1018.6
#
#        평균상대습도  월합강수량  평균풍속   일조시간  최심적설
# 0        47.0    0.0   2.1  218.6   NaN
# 1        51.0    3.3   2.2  236.5   1.8
# 2        57.0    8.8   2.1  223.7   0.0
# 3        63.0    6.9   2.0  255.7   NaN
# 4        74.0   49.1   2.2  187.8   NaN
# ...       ...    ...   ...    ...   ...
# 54430    82.0  473.2   1.3  174.5   NaN
# 54431    82.0  164.6   1.5   95.2   NaN
# 54432    74.0   43.6   1.3  203.2   NaN
# 54433    67.0   53.5   1.6  178.9   NaN
# 54434    60.0    2.4   1.8  184.0   NaN
#
# [54435 rows x 14 columns]

# %% [markdown]
# ### [실습] : 2중 축 그래프 그리기 :  평균상대습도 & 월합강수량

# %%
# 2.'제주'지점의 평균상대습도 & 일최다강수량 센터수
data = df.groupby(['지점명','년도'])['평균상대습도'].agg(**{'평균상대습도':'mean'}).reset_index()
data = data.query(" 지점명 == '제주' ")
X  = data['년도']
Y1 = data['평균상대습도']

data = df.groupby(['지점명','년도'])['월합강수량'].agg(**{'월합강수량':'mean'}).reset_index()
data = data.query(" 지점명 == '제주' ")
Y2 = data['월합강수량']
print(Y2)


# 3. 그래프로 시각화하기 
plt.rcParams['figure.figsize'] = (10, 5)   # 그래프 크기

fig, ax1 = plt.subplots()        
plt.suptitle('평균상대습도 & 월합강수량',fontsize=15)

ax1.plot(X, Y1, color='green')     # 평균상대습도 (왼쪽)
ax2 = ax1.twinx()
ax2.plot(X, Y2, color='deeppink')  # 월합강수량 (오른쪽)

fig.autofmt_xdate(rotation=45)  #X축 레이블 기울이기

plt.show()
# Out:
# 3531    156.487500
# 3532    102.250000
# 3533    134.400000
# 3534     79.741667
# 3535    170.175000
#            ...
# 3625     64.441667
# 3626    147.458333
# 3627    164.991667
# 3628    115.791667
# 3629    135.641667
# Name: 월합강수량, Length: 99, dtype: float64

# %% [markdown]
# -------

# %% [markdown]
# 끝!
